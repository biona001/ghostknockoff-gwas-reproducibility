# %% [markdown]
# # Simulation with Pan-UKBB LD panel
#
# Simulation script

# %%
# ml julia/1.8.4
# export JULIA_DEPOT_PATH="/home/groups/sabatti/.julia"

using Knockoffs
using LinearAlgebra
using Random
using StatsBase
using Statistics
using ToeplitzMatrices
using Distributions
using DataFrames, CSV
using DelimitedFiles
using GLM
using JLD2
using HDF5

# rep_threshold = representative cutoff value
# 1 = every variable selected, 0 = one variable selected in each group
function run_group_knockoff(seed::Int, rep_threshold::Float64, chr, start_pos, end_pos)
    simdir = "/home/groups/sabatti/group_knockoff_simulations/pan_ukbb"
    outdir = joinpath(simdir, "c$(rep_threshold)", "sim$seed")
    isdir(outdir) || mkpath(outdir)

    # parameters
    n = 250
    k = 50
    m = 5
    knockoff_methods = [:equi, :sdp, :maxent, :mvr]
    target_fdrs = collect(0.01:0.01:0.2)

    # read a region of LD into memory
    knockoff_dir = "/oak/stanford/groups/zihuai/pan_ukb_group_knockoffs/EUR"
    LD = JLD2.load(joinpath(knockoff_dir, "chr$chr/LD_start$(start_pos)_end$(end_pos).h5"))
    Σ = LD["Sigma"]
    p = size(Σ, 1)
    μ = zeros(p)

    # simulate X
    Random.seed!(seed)
#     X = rand(MvNormal(Symmetric(Σ)), n)' |> Matrix{Float64}
    L = cholesky(Symmetric(Σ))
    X = randn(n, p) * L.L
    zscore!(X, mean(X, dims=1), std(X, dims=1))

    # simulate y and beta
    βtrue = zeros(p)
    βtrue[1:k] .= randn(k) # rand(Normal(0, 0.5), k)
    shuffle!(βtrue)
    ϵ = randn(n)
    y = X * βtrue + ϵ

    # define group
    groups = LD["groups"]
    correct_groups = groups[findall(!iszero, βtrue)] |> unique

    for method in knockoff_methods
        df = DataFrame(power=Float64[], fdr=Float64[], 
            time=Float64[], ssum=Float64[], obj=Float64[], mineval=Float64[])

        # generate knockoffs
        my_t = @elapsed begin
            0 < rep_threshold <= 1 || error("expected rep_threshold ∈ (0, 1]")
            if rep_threshold == 1
                ko = modelX_gaussian_group_knockoffs(X, method, groups, μ, Σ, m=m)
            else
                ko = modelX_gaussian_rep_group_knockoffs(X, method, groups, μ, Σ, 
                        m=m, rep_threshold=rep_threshold)
            end
        end

        # knockoff filter
        ko_filter = fit_lasso(y, ko, fdrs=target_fdrs)
        my_ssum = sum(abs.(ko.S))
        my_obj = ko.obj
        constraint = eigmin(Symmetric((m+1)/m*Σ - ko.S))
        if constraint < -0.0001
            error("min eval of (m+1)/m*Σ - S) is less than -0.0001")
        end

        # save output
        for (i, fdr) in enumerate(target_fdrs)
            selected = ko_filter.selected[i]
            my_power = length(intersect(correct_groups, selected)) / length(correct_groups)
            my_fdr = length(setdiff(selected, correct_groups)) / max(1, length(selected))
            println("sim $seed $method fdr $fdr: power = $(my_power), fdr = $(my_fdr), time = $(my_t), ssum = $(my_ssum), obj=$(my_obj), min eval = $constraint")
            push!(df, [my_power, my_fdr, my_t, my_ssum, my_obj, constraint])
        end
        CSV.write(joinpath(outdir, "$(method)_$(rep_threshold).csv"), df)
    end
end

# input parameters
# seed = 1116
seed = parse(Int, ARGS[1])

# select a random region to work with
Random.seed!(seed)
region_file = "/oak/stanford/groups/zihuai/pan_ukb_LD_matrices/LD_block/EUR_hg19/fourier_ls-all.bed"
df = CSV.read(region_file, DataFrame)
region = rand(1:size(df, 1))
chr = parse(Int, rstrip(df[region, 1])[4:end])
start_pos = df[region, 2]
end_pos = df[region, 3] - 1

for rep_threshold in [0.25, 0.5, 0.75, 1.0]
    @time run_group_knockoff(seed, rep_threshold, chr, start_pos, end_pos)
end
println("finished")

# %% [markdown]
# submission scripts

# %%
function run_repeats()
    outdir = "/home/groups/sabatti/group_knockoff_simulations"
    for sim in 101:500
        # create .sh file to submit jobs
        filename = "submit.sh"
        open(filename, "w") do io
            println(io, "#!/bin/bash")
            println(io, "#")
            println(io, "#SBATCH --job-name=ukb$sim")
            println(io, "#")
            println(io, "#SBATCH --time=24:00:00")
            println(io, "#SBATCH --cpus-per-task=1")
            println(io, "#SBATCH --mem-per-cpu=8G")
            println(io, "#SBATCH --partition=owners,normal,candes,zihuai")
            println(io, "#SBATCH --output=$(outdir)/pan_ukbb/slurms/slurm-%j.out")
            println(io, "")
            println(io, "#save job info on joblog:")
            println(io, "echo \"Job \$JOB_ID started on:   \" `hostname -s`")
            println(io, "echo \"Job \$JOB_ID started on:   \" `date `")
            println(io, "")
            println(io, "# load the job environment:")
            println(io, "module load julia/1.8.4")
            println(io, "export JULIA_DEPOT_PATH=\"/home/groups/sabatti/.julia\"")
            println(io, "")
            println(io, "# run code")
            println(io, "echo 'julia $(outdir)/run_ukb.jl $sim'")
            println(io, "julia $(outdir)/run_ukb.jl $sim")
            println(io, "")
            println(io, "#echo job info on joblog:")
            println(io, "echo \"Job \$JOB_ID ended on:   \" `hostname -s`")
            println(io, "echo \"Job \$JOB_ID ended on:   \" `date `")
            println(io, "#echo \" \"")
        end
        # submit job
        run(`sbatch $filename`)
        println("submitted sim$sim") 
        rm(filename, force=true)
    end
end
run_repeats()
# Out:
# Submitted batch job 27856866
# submitted sim101
# Submitted batch job 27856868
# submitted sim102
# Submitted batch job 27856871
# submitted sim103
# Submitted batch job 27856873
# submitted sim104
# Submitted batch job 27856875
# submitted sim105
# Submitted batch job 27856877
# submitted sim106
# Submitted batch job 27856879
# submitted sim107
# Submitted batch job 27856881
# submitted sim108
# Submitted batch job 27856883
# submitted sim109
# Submitted batch job 27856885
# submitted sim110
# Submitted batch job 27856887
# submitted sim111
# Submitted batch job 27856890
# submitted sim112
# Submitted batch job 27856893
# submitted sim113
# Submitted batch job 27856895
# submitted sim114
# Submitted batch job 27856898
# submitted sim115
# Submitted batch job 27856901
# submitted sim116
# Submitted batch job 27856904
# submitted sim117
# Submitted batch job 27856907
# submitted sim118
# Submitted batch job 27856910
# submitted sim119
# Submitted batch job 27856912
# submitted sim120
# Submitted batch job 27856914
# submitted sim121
# Submitted batch job 27856917
# submitted sim122
# Submitted batch job 27856920
# submitted sim123
# Submitted batch job 27856923
# submitted sim124
# Submitted batch job 27856925
# submitted sim125
# Submitted batch job 27856927
# submitted sim126
# Submitted batch job 27856930
# submitted sim127
# Submitted batch job 27856932
# submitted sim128
# Submitted batch job 27856934
# submitted sim129
# Submitted batch job 27856937
# submitted sim130
# Submitted batch job 27856939
# submitted sim131
# Submitted batch job 27856941
# submitted sim132
# Submitted batch job 27856944
# submitted sim133
# Submitted batch job 27856947
# submitted sim134
# Submitted batch job 27856950
# submitted sim135
# Submitted batch job 27856953
# submitted sim136
# Submitted batch job 27856955
# submitted sim137
# Submitted batch job 27856958
# submitted sim138
# Submitted batch job 27856961
# submitted sim139
# Submitted batch job 27856964
# submitted sim140
# Submitted batch job 27856967
# submitted sim141
# Submitted batch job 27856970
# submitted sim142
# Submitted batch job 27856973
# submitted sim143
# Submitted batch job 27856977
# submitted sim144
# Submitted batch job 27856979
# submitted sim145
# Submitted batch job 27856981
# submitted sim146
# Submitted batch job 27856984
# submitted sim147
# Submitted batch job 27856986
# submitted sim148
# Submitted batch job 27856989
# submitted sim149
# Submitted batch job 27856991
# submitted sim150
# Submitted batch job 27856993
# submitted sim151
# Submitted batch job 27856996
# submitted sim152
# Submitted batch job 27856999
# submitted sim153
# Submitted batch job 27857001
# submitted sim154
# Submitted batch job 27857004
# submitted sim155
# Submitted batch job 27857007
# submitted sim156
# Submitted batch job 27857010
# submitted sim157
# Submitted batch job 27857013
# submitted sim158
# Submitted batch job 27857016
# submitted sim159
# Submitted batch job 27857018
# submitted sim160
# Submitted batch job 27857021
# submitted sim161
# Submitted batch job 27857023
# submitted sim162
# Submitted batch job 27857026
# submitted sim163
# Submitted batch job 27857028
# submitted sim164
# Submitted batch job 27857030
# submitted sim165
# Submitted batch job 27857033
# submitted sim166
# Submitted batch job 27857036
# submitted sim167
# Submitted batch job 27857039
# submitted sim168
# Submitted batch job 27857041
# submitted sim169
# Submitted batch job 27857044
# submitted sim170
# Submitted batch job 27857048
# submitted sim171
# Submitted batch job 27857051
# submitted sim172
# Submitted batch job 27857054
# submitted sim173
# Submitted batch job 27857056
# submitted sim174
# Submitted batch job 27857058
# submitted sim175
# Submitted batch job 27857061
# submitted sim176
# Submitted batch job 27857063
# submitted sim177
# Submitted batch job 27857066
# submitted sim178
# Submitted batch job 27857069
# submitted sim179
# Submitted batch job 27857072
# submitted sim180
# Submitted batch job 27857075
# submitted sim181
# Submitted batch job 27857078
# submitted sim182
# Submitted batch job 27857081
# submitted sim183
# Submitted batch job 27857084
# submitted sim184
# Submitted batch job 27857087
# submitted sim185
# Submitted batch job 27857090
# submitted sim186
# Submitted batch job 27857093
# submitted sim187
# Submitted batch job 27857096
# submitted sim188
# Submitted batch job 27857098
# submitted sim189
# Submitted batch job 27857100
# submitted sim190
# Submitted batch job 27857103
# submitted sim191
# Submitted batch job 27857105
# submitted sim192
# Submitted batch job 27857107
# submitted sim193
# Submitted batch job 27857109
# submitted sim194
# Submitted batch job 27857112
# submitted sim195
# Submitted batch job 27857114
# submitted sim196
# Submitted batch job 27857116
# submitted sim197
# Submitted batch job 27857119
# submitted sim198
# Submitted batch job 27857121
# submitted sim199
# Submitted batch job 27857124
# submitted sim200
# Submitted batch job 27857126
# submitted sim201
# Submitted batch job 27857129
# submitted sim202
# Submitted batch job 27857131
# submitted sim203
# Submitted batch job 27857134
# submitted sim204
# Submitted batch job 27857137
# submitted sim205
# Submitted batch job 27857140
# submitted sim206
# Submitted batch job 27857141
# submitted sim207
# Submitted batch job 27857144
# submitted sim208
# Submitted batch job 27857147
# submitted sim209
# Submitted batch job 27857150
# submitted sim210
# Submitted batch job 27857153
# submitted sim211
# Submitted batch job 27857156
# submitted sim212
# Submitted batch job 27857159
# submitted sim213
# Submitted batch job 27857162
# submitted sim214
# Submitted batch job 27857164
# submitted sim215
# Submitted batch job 27857167
# submitted sim216
# Submitted batch job 27857170
# submitted sim217
# Submitted batch job 27857173
# submitted sim218
# Submitted batch job 27857176
# submitted sim219
# Submitted batch job 27857179
# submitted sim220
# Submitted batch job 27857182
# submitted sim221
# Submitted batch job 27857185
# submitted sim222
# Submitted batch job 27857188
# submitted sim223
# Submitted batch job 27857191
# submitted sim224
# Submitted batch job 27857193
# submitted sim225
# Submitted batch job 27857196
# submitted sim226
# Submitted batch job 27857199
# submitted sim227
# Submitted batch job 27857202
# submitted sim228
# Submitted batch job 27857204
# submitted sim229
# Submitted batch job 27857207
# submitted sim230
# Submitted batch job 27857209
# submitted sim231
# Submitted batch job 27857211
# submitted sim232
# Submitted batch job 27857214
# submitted sim233
# Submitted batch job 27857217
# submitted sim234
# Submitted batch job 27857220
# submitted sim235
# Submitted batch job 27857221
# submitted sim236
# Submitted batch job 27857223
# submitted sim237
# Submitted batch job 27857225
# submitted sim238
# Submitted batch job 27857228
# submitted sim239
# Submitted batch job 27857231
# submitted sim240
# Submitted batch job 27857234
# submitted sim241
# Submitted batch job 27857237
# submitted sim242
# Submitted batch job 27857239
# submitted sim243
# Submitted batch job 27857242
# submitted sim244
# Submitted batch job 27857244
# submitted sim245
# Submitted batch job 27857247
# submitted sim246
# Submitted batch job 27857250
# submitted sim247
# Submitted batch job 27857253
# submitted sim248
# Submitted batch job 27857255
# submitted sim249
# Submitted batch job 27857258
# submitted sim250
# Submitted batch job 27857261
# submitted sim251
# Submitted batch job 27857266
# submitted sim252
# Submitted batch job 27857268
# submitted sim253
# Submitted batch job 27857270
# submitted sim254
# Submitted batch job 27857273
# submitted sim255
# Submitted batch job 27857274
# submitted sim256
# Submitted batch job 27857276
# submitted sim257
# Submitted batch job 27857279
# submitted sim258
# Submitted batch job 27857282
# submitted sim259
# Submitted batch job 27857284
# submitted sim260
# Submitted batch job 27857286
# submitted sim261
# Submitted batch job 27857290
# submitted sim262
# Submitted batch job 27857292
# submitted sim263
# Submitted batch job 27857294
# submitted sim264
# Submitted batch job 27857297
# submitted sim265
# Submitted batch job 27857299
# submitted sim266
# Submitted batch job 27857303
# submitted sim267
# Submitted batch job 27857305
# submitted sim268
# Submitted batch job 27857308
# submitted sim269
# Submitted batch job 27857311
# submitted sim270
# Submitted batch job 27857314
# submitted sim271
# Submitted batch job 27857317
# submitted sim272
# Submitted batch job 27857320
# submitted sim273
# Submitted batch job 27857322
# submitted sim274
# Submitted batch job 27857325
# submitted sim275
# Submitted batch job 27857328
# submitted sim276
# Submitted batch job 27857331
# submitted sim277
# Submitted batch job 27857334
# submitted sim278
# Submitted batch job 27857337
# submitted sim279
# Submitted batch job 27857340
# submitted sim280
# Submitted batch job 27857343
# submitted sim281
# Submitted batch job 27857344
# submitted sim282
# Submitted batch job 27857346
# submitted sim283
# Submitted batch job 27857348
# submitted sim284
# Submitted batch job 27857351
# submitted sim285
# Submitted batch job 27857354
# submitted sim286
# Submitted batch job 27857357
# submitted sim287
# Submitted batch job 27857359
# submitted sim288
# Submitted batch job 27857361
# submitted sim289
# Submitted batch job 27857364
# submitted sim290
# Submitted batch job 27857366
# submitted sim291
# Submitted batch job 27857368
# submitted sim292
# Submitted batch job 27857370
# submitted sim293
# Submitted batch job 27857373
# submitted sim294
# Submitted batch job 27857375
# submitted sim295
# Submitted batch job 27857378
# submitted sim296
# Submitted batch job 27857381
# submitted sim297
# Submitted batch job 27857383
# submitted sim298
# Submitted batch job 27857385
# submitted sim299
# Submitted batch job 27857389
# submitted sim300
# Submitted batch job 27857391
# submitted sim301
# Submitted batch job 27857393
# submitted sim302
# Submitted batch job 27857395
# submitted sim303
# Submitted batch job 27857398
# submitted sim304
# Submitted batch job 27857400
# submitted sim305
# Submitted batch job 27857403
# submitted sim306
# Submitted batch job 27857406
# submitted sim307
# Submitted batch job 27857408
# submitted sim308
# Submitted batch job 27857411
# submitted sim309
# Submitted batch job 27857413
# submitted sim310
# Submitted batch job 27857421
# submitted sim311
# Submitted batch job 27857422
# submitted sim312
# Submitted batch job 27857425
# submitted sim313
# Submitted batch job 27857427
# submitted sim314
# Submitted batch job 27857430
# submitted sim315
# Submitted batch job 27857432
# submitted sim316
# Submitted batch job 27857443
# submitted sim317
# Submitted batch job 27857445
# submitted sim318
# Submitted batch job 27857450
# submitted sim319
# Submitted batch job 27857453
# submitted sim320
# Submitted batch job 27857456
# submitted sim321
# Submitted batch job 27857458
# submitted sim322
# Submitted batch job 27857460
# submitted sim323
# Submitted batch job 27857462
# submitted sim324
# Submitted batch job 27857465
# submitted sim325
# Submitted batch job 27857468
# submitted sim326
# Submitted batch job 27857470
# submitted sim327
# Submitted batch job 27857474
# submitted sim328
# Submitted batch job 27857477
# submitted sim329
# Submitted batch job 27857479
# submitted sim330
# Submitted batch job 27857482
# submitted sim331
# Submitted batch job 27857485
# submitted sim332
# Submitted batch job 27857488
# submitted sim333
# Submitted batch job 27857491
# submitted sim334
# Submitted batch job 27857493
# submitted sim335
# Submitted batch job 27857495
# submitted sim336
# Submitted batch job 27857498
# submitted sim337
# Submitted batch job 27857500
# submitted sim338
# Submitted batch job 27857502
# submitted sim339
# Submitted batch job 27857505
# submitted sim340
# Submitted batch job 27857507
# submitted sim341
# Submitted batch job 27857509
# submitted sim342
# Submitted batch job 27857513
# submitted sim343
# Submitted batch job 27857515
# submitted sim344
# Submitted batch job 27857517
# submitted sim345
# Submitted batch job 27857519
# submitted sim346
# Submitted batch job 27857521
# submitted sim347
# Submitted batch job 27857523
# submitted sim348
# Submitted batch job 27857525
# submitted sim349
# Submitted batch job 27857528
# submitted sim350
# Submitted batch job 27857534
# submitted sim351
# Submitted batch job 27857536
# submitted sim352
# Submitted batch job 27857538
# submitted sim353
# Submitted batch job 27857541
# submitted sim354
# Submitted batch job 27857544
# submitted sim355
# Submitted batch job 27857546
# submitted sim356
# Submitted batch job 27857547
# submitted sim357
# Submitted batch job 27857549
# submitted sim358
# Submitted batch job 27857552
# submitted sim359
# Submitted batch job 27857554
# submitted sim360
# Submitted batch job 27857557
# submitted sim361
# Submitted batch job 27857560
# submitted sim362
# Submitted batch job 27857562
# submitted sim363
# Submitted batch job 27857564
# submitted sim364
# Submitted batch job 27857566
# submitted sim365
# Submitted batch job 27857569
# submitted sim366
# Submitted batch job 27857573
# submitted sim367
# Submitted batch job 27857575
# submitted sim368
# Submitted batch job 27857578
# submitted sim369
# Submitted batch job 27857581
# submitted sim370
# Submitted batch job 27857592
# submitted sim371
# Submitted batch job 27857594
# submitted sim372
# Submitted batch job 27857597
# submitted sim373
# Submitted batch job 27857600
# submitted sim374
# Submitted batch job 27857603
# submitted sim375
# Submitted batch job 27857606
# submitted sim376
# Submitted batch job 27857608
# submitted sim377
# Submitted batch job 27857610
# submitted sim378
# Submitted batch job 27857612
# submitted sim379
# Submitted batch job 27857614
# submitted sim380
# Submitted batch job 27857617
# submitted sim381
# Submitted batch job 27857620
# submitted sim382
# Submitted batch job 27857623
# submitted sim383
# Submitted batch job 27857626
# submitted sim384
# Submitted batch job 27857628
# submitted sim385
# Submitted batch job 27857630
# submitted sim386
# Submitted batch job 27857633
# submitted sim387
# Submitted batch job 27857636
# submitted sim388
# Submitted batch job 27857638
# submitted sim389
# Submitted batch job 27857641
# submitted sim390
# Submitted batch job 27857645
# submitted sim391
# Submitted batch job 27857647
# submitted sim392
# Submitted batch job 27857649
# submitted sim393
# Submitted batch job 27857652
# submitted sim394
# Submitted batch job 27857654
# submitted sim395
# Submitted batch job 27857656
# submitted sim396
# Submitted batch job 27857658
# submitted sim397
# Submitted batch job 27857660
# submitted sim398
# Submitted batch job 27857663
# submitted sim399
# Submitted batch job 27857666
# submitted sim400
# Submitted batch job 27857669
# submitted sim401
# Submitted batch job 27857672
# submitted sim402
# Submitted batch job 27857675
# submitted sim403
# Submitted batch job 27857677
# submitted sim404
# Submitted batch job 27857680
# submitted sim405
# Submitted batch job 27857683
# submitted sim406
# Submitted batch job 27857686
# submitted sim407
# Submitted batch job 27857689
# submitted sim408
# Submitted batch job 27857692
# submitted sim409
# Submitted batch job 27857695
# submitted sim410
# Submitted batch job 27857699
# submitted sim411
# Submitted batch job 27857701
# submitted sim412
# Submitted batch job 27857703
# submitted sim413
# Submitted batch job 27857705
# submitted sim414
# Submitted batch job 27857709
# submitted sim415
# Submitted batch job 27857712
# submitted sim416
# Submitted batch job 27857715
# submitted sim417
# Submitted batch job 27857717
# submitted sim418
# Submitted batch job 27857720
# submitted sim419
# Submitted batch job 27857723
# submitted sim420
# Submitted batch job 27857726
# submitted sim421
# Submitted batch job 27857729
# submitted sim422
# Submitted batch job 27857732
# submitted sim423
# Submitted batch job 27857735
# submitted sim424
# Submitted batch job 27857738
# submitted sim425
# Submitted batch job 27857741
# submitted sim426
# Submitted batch job 27857742
# submitted sim427
# Submitted batch job 27857746
# submitted sim428
# Submitted batch job 27857749
# submitted sim429
# Submitted batch job 27857751
# submitted sim430
# Submitted batch job 27857754
# submitted sim431
# Submitted batch job 27857757
# submitted sim432
# Submitted batch job 27857759
# submitted sim433
# Submitted batch job 27857763
# submitted sim434
# Submitted batch job 27857766
# submitted sim435
# Submitted batch job 27857768
# submitted sim436
# Submitted batch job 27857770
# submitted sim437
# Submitted batch job 27857772
# submitted sim438
# Submitted batch job 27857776
# submitted sim439
# Submitted batch job 27857778
# submitted sim440
# Submitted batch job 27857781
# submitted sim441
# Submitted batch job 27857784
# submitted sim442
# Submitted batch job 27857786
# submitted sim443
# Submitted batch job 27857790
# submitted sim444
# Submitted batch job 27857793
# submitted sim445
# Submitted batch job 27857795
# submitted sim446
# Submitted batch job 27857796
# submitted sim447
# Submitted batch job 27857799
# submitted sim448
# Submitted batch job 27857802
# submitted sim449
# Submitted batch job 27857805
# submitted sim450
# Submitted batch job 27857807
# submitted sim451
# Submitted batch job 27857810
# submitted sim452
# Submitted batch job 27857813
# submitted sim453
# Submitted batch job 27857815
# submitted sim454
# Submitted batch job 27857818
# submitted sim455
# Submitted batch job 27857820
# submitted sim456
# Submitted batch job 27857823
# submitted sim457
# Submitted batch job 27857825
# submitted sim458
# Submitted batch job 27857828
# submitted sim459
# Submitted batch job 27857831
# submitted sim460
# Submitted batch job 27857833
# submitted sim461
# Submitted batch job 27857835
# submitted sim462
# Submitted batch job 27857837
# submitted sim463
# Submitted batch job 27857839
# submitted sim464
# Submitted batch job 27857841
# submitted sim465
# Submitted batch job 27857844
# submitted sim466
# Submitted batch job 27857846
# submitted sim467
# Submitted batch job 27857848
# submitted sim468
# Submitted batch job 27857850
# submitted sim469
# Submitted batch job 27857852
# submitted sim470
# Submitted batch job 27857855
# submitted sim471
# Submitted batch job 27857858
# submitted sim472
# Submitted batch job 27857861
# submitted sim473
# Submitted batch job 27857864
# submitted sim474
# Submitted batch job 27857867
# submitted sim475
# Submitted batch job 27857870
# submitted sim476
# Submitted batch job 27857872
# submitted sim477
# Submitted batch job 27857875
# submitted sim478
# Submitted batch job 27857879
# submitted sim479
# Submitted batch job 27857881
# submitted sim480
# Submitted batch job 27857883
# submitted sim481
# Submitted batch job 27857885
# submitted sim482
# Submitted batch job 27857888
# submitted sim483
# Submitted batch job 27857890
# submitted sim484
# Submitted batch job 27857893
# submitted sim485
# Submitted batch job 27857895
# submitted sim486
# Submitted batch job 27857897
# submitted sim487
# Submitted batch job 27857899
# submitted sim488
# Submitted batch job 27857901
# submitted sim489
# Submitted batch job 27857903
# submitted sim490
# Submitted batch job 27857906
# submitted sim491
# Submitted batch job 27857908
# submitted sim492
# Submitted batch job 27857910
# submitted sim493
# Submitted batch job 27857912
# submitted sim494
# Submitted batch job 27857915
# submitted sim495
# Submitted batch job 27857917
# submitted sim496
# Submitted batch job 27857919
# submitted sim497
# Submitted batch job 27857921
# submitted sim498
# Submitted batch job 27857924
# submitted sim499
# Submitted batch job 27857927
# submitted sim500

# %% [markdown]
# ## Make plots

# %%
using ProgressMeter
using DataFrames, CSV
using Plots
using LinearAlgebra
using Statistics
gr(fmt=:png);

global titlefontsize=10
global legendfontsize=10
global labelfontsize=10
global annotationfontsize=10
global guidefontsize=10
global my_colors = ["gold", "orangered2", "mediumblue", "cyan3"];

# %%
function summarize_ukb(method, rep_threshold, target_fdrs = 0.01:0.01:0.2)
    dir = "/home/groups/sabatti/group_knockoff_simulations/pan_ukbb/c$(rep_threshold)"
    powers = zeros(length(target_fdrs))
    fdrs = zeros(length(target_fdrs))
    success = 0
    for seed in 1:500
        try
            result = CSV.read(joinpath(dir, "sim$seed", "$(method)_$(rep_threshold).csv"), DataFrame)
            powers .+= result[1:length(target_fdrs), 1]
            fdrs .+= result[1:length(target_fdrs), 2]
            success += 1
        catch
            continue
        end
    end
#     @show success
    powers ./= success
    fdrs ./= success
    return powers, fdrs
end

function make_plot_ukb(rep_threshold; target_fdrs = 0.01:0.01:0.2)
    ko_methods = ["equi", "sdp", "maxent", "mvr"]
    ko_labels = ["Equi", "SDP", "ME", "MVR"]

    # output plots
    title = "c = $rep_threshold"
    if rep_threshold == 0.25
        power_plt = plot(; title = title, xtick=false, ylim=(0, 0.8), ylabel="Power",
            legend=false, left_margin = 5Plots.mm, titlefontsize=titlefontsize,
            guidefontsize=guidefontsize, labelfontsize=labelfontsize)
        fdr_plt = plot(; xlabel="target FDR", ylim=(0, 0.3), ylabel="FDR", legend=false, 
            xgrid=false, left_margin = 5Plots.mm, guidefontsize=guidefontsize,
            labelfontsize=labelfontsize)
    else
        power_plt = plot(; title = title, ylim=(0, 0.8), 
            legend=false, xtick=false, ytick=(0.0:0.2:0.8, ["", "", "", "", ""]),
            titlefontsize=titlefontsize, guidefontsize=guidefontsize,
            labelfontsize=labelfontsize)
        fdr_plt = plot(; xlabel="target FDR", ylim=(0, 0.3), legend=false, 
            xgrid=false, ytick=(0.0:0.05:0.25, ["", "", "", "", "", ""]),
            guidefontsize=guidefontsize,
            labelfontsize=labelfontsize)
    end

    # loop over knockoff results
    for (i, method) in enumerate(ko_methods)
        label = ko_labels[i]
        power, fdr = summarize_ukb(method, rep_threshold)
        plot!(power_plt, target_fdrs, power, label=label, w=3, color=my_colors[i])
        plot!(fdr_plt, target_fdrs, fdr, w=3, label="", color=my_colors[i])
    end
    Plots.abline!(fdr_plt, 1, 0, alpha=0.3, w=2, linestyle=:dot, color=:black)#, label="Expected FDR")

    return power_plt, fdr_plt
end

# group/rep-group plots
plts = []
for rep_threshold in [0.25, 0.5, 0.75, 1.0]
    ukb_power_plt, ukb_fdr_plt = make_plot_ukb(rep_threshold)
    plt = plot(ukb_power_plt, ukb_fdr_plt, layout = grid(2, 1, heights=[0.7 ,0.3]))
    push!(plts, plt)
end

# separate plot for legend
n = 5
labels = ["eSDP" "SDP" "ME" "MVR"]
lstyles = [:solid :solid :solid :solid]
legend_plt = plot(2:n,2:n, lims=(0,1), legendfontsize=legendfontsize, legend=:outerbottom, 
    legendcolumns=n, frame=:none, fg_color_legend = nothing, w=3,
    label=labels[1], color=my_colors[1], linestyle=lstyles[1])
plot!(legend_plt, 2:n, 2:n, label=labels[2], color=my_colors[2], w=3,linestyle=lstyles[2])
plot!(legend_plt, 2:n, 2:n, label=labels[3], color=my_colors[3], w=3,linestyle=lstyles[3])
plot!(legend_plt, 2:n, 2:n, label=labels[4], color=my_colors[4], w=3,linestyle=lstyles[4])
# plot!(legend_plt, 2:n, 2:n, label="target FDR", color="black", alpha=0.3, w=2, linestyle=:dot)

# combine plots
combined = plot(plts..., size=(900, 500), layout=(1, 4))
plt = plot(combined, legend_plt, layout = grid(2, 1, heights=[0.87, 0.13]), dpi=300)
# Out:
# ┌ Warning: n° of legend_column=5 is larger than n° of series=4
# └ @ Plots /home/groups/sabatti/.julia/packages/Plots/7XeYS/src/backends/gr.jl:1235

# %%
savefig(plt, "/home/users/bbchu/knockoffs/plots/sim2.pdf")
# Out:
# ┌ Warning: n° of legend_column=5 is larger than n° of series=4
# └ @ Plots /home/groups/sabatti/.julia/packages/Plots/7XeYS/src/backends/gr.jl:1235
# "/home/users/bbchu/knockoffs/plots/sim2.pdf"
