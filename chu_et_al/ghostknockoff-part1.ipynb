# %% [markdown]
# # Part 1: Pipeline for generating S and Sigma from Pan-UKB LD panel
#
# Currently this pipeline solves for $S$ in each quasi-independent region and saves them in `.h5`, which seems even faster to read than `gds` files.
#
# Code was tested on Sherlock with
# + `openssl/3.0.7`
# + `julia/1.8.4`
# + `R/4.0.2`
# + `java/11.0.11`
# + `python/3.9.0`
#
# `ml julia/1.8.4 R/4.0.2 openssl/3.0.7 java/11.0.11 python/3.9.0`
#
# Installing R libraries:
# ```R
# # ml system
# # ml openssl
# # ml R/4.0.2
# install.packages("BiocManager", repos='http://cran.us.r-project.org')
# install.packages("openssl", repos='http://cran.us.r-project.org')
# BiocManager::install("gwascat")
# BiocManager::install("liftOver")
# BiocManager::install("gwascat", lib="~/R")
# BiocManager::install("liftOver", lib="~/R")
# ```

# %% [markdown]
# ## Quasi-independent regions from ldetect
#
# The original data (genome build hg19) is downloaded from: https://bitbucket.org/nygcresearch/ldetect-data/src/master/

# %% [markdown]
# # Script to solve knockoff problem across the genome
#
# + The code below was used to solve the knockoff problem across different quasi-independent LD blocks
# + It requires 12 different inputs
# + To use this script, copy the file below to a file, e.g. `run_script.jl` and in the terminal, execute
# ```
# julia run_script.jl arg1 arg2 arg3 ...
# ```

# %%
# ml julia/1.8.4 R/4.0.2 java/11.0.11 python/3.9.0 openssl/3.0.7 system

sleep(60rand()) # prevent too many jobs starting at the same time

using CSV
using DataFrames
using EasyLD
using Knockoffs
using LinearAlgebra
using StatsBase
using DelimitedFiles
using JLD2
using HDF5
using RCall
R"library(liftOver)"

function graphical_group_S(
    bm_file::String, # path to the `.bm` hail block matrix folder
    ht_file::String, # path to the `.ht` hail variant index folder
    chr::String, # 1, 2, ..., 22, or X/Y/M
    start_pos::Int, 
    end_pos::Int, 
    outdir::String;
    m=5,
    tol=0.0001, 
    min_maf=0.01, # only SNPs with maf > min_maf will be included in Sigma
    snps_to_keep=nothing, # list of position (if provided, only SNPs in snps_to_keep will be included in Sigma)
    force_block_diag=true, # whether to reorder row/col of S/Sigma/etc so S is returned as block diagonal 
    add_hg38_coordinates=true, # whether to augment Sigma_info with hg38 coordinates. SNPs that cannot be mapped to hg38 will be deleted
    liftOver_chain_dir::String = "",
    method::Symbol = :maxent,
    group_def::String="hc",
    rk::Number=Inf, # minimum rank of Σ before truncating the remaining eigvals to `min_maf`
    verbose=true
    )
    isdir(outdir) || error("output directory $outdir does not exist!")
    group_def ∈ ["hc", "id"] || error("group_def should be \"hc\" or \"id\"")
    add_hg38_coordinates && !isfile(liftOver_chain_dir) && 
        error("To add hg38 coordinates, a liftOver chain file is required")

    # import Sigma
    import_sigma_time = @elapsed begin
        bm = hail_block_matrix(bm_file, ht_file);
        Sigma, Sigma_info = get_block(bm, chr, start_pos, end_pos, 
            min_maf=min_maf, snps_to_keep=snps_to_keep, enforce_psd=true)
    end

    # append hg38 coordinates to Sigma_info and remove SNPs that can't be converted to hg38
    if add_hg38_coordinates
        Sigma, Sigma_info = augment_hg38(Sigma_info, Sigma, chr, liftOver_chain_dir)
    end

    # define groups and representatives
    def_group_time = @elapsed begin
        groups = group_def == "hc" ? 
            hc_partition_groups(Symmetric(Sigma), cutoff=0.5, linkage=:average) : 
            id_partition_groups(Symmetric(Sigma), rss_target=0.5)
        group_reps = choose_group_reps(Symmetric(Sigma), groups, threshold=0.5)
    end

    # reorder SNPs so D2/S2 is really block diagonal
    if force_block_diag
        rearrange_snps!(groups, group_reps, Sigma, Sigma_info)
    end

    # solve for S
    solve_S_time = @elapsed begin
        # solve S using original Sigma
        S, D, obj = solve_s_graphical_group(Symmetric(Sigma), groups, group_reps, method,
            m=m, tol=tol, verbose=verbose)

        # solve S using modified Sigma (enforcing conditional independence)
        # Sigma2 = cond_indep_corr(Sigma, groups, group_reps)
        # S2, D2, obj2 = solve_s_graphical_group(Symmetric(Sigma2), groups, group_reps, method,
        #     m=m, tol=tol, verbose=verbose)
    end

    # save result in .h5 format
    dir = joinpath(outdir, "chr$chr")
    isdir(dir) || mkpath(dir)
    JLD2.save(
        joinpath(dir, "LD_start$(start_pos)_end$(end_pos).h5"), 
        Dict(
            "S" => S,
            "D" => D,
            "Sigma" => Sigma,
            "SigmaInv" => inv(Sigma),
            "groups" => groups,
            "group_reps" => group_reps,
            "Sigma_reps" => Sigma[group_reps, group_reps],
            "Sigma_reps_inv" => inv(Sigma[group_reps, group_reps])
        )
    )
    CSV.write(joinpath(dir, "Info_start$(start_pos)_end$(end_pos).csv"), Sigma_info)
    open(joinpath(dir, "summary_start$(start_pos)_end$(end_pos).csv"), "w") do io
        println(io, "chr,$chr")
        println(io, "start_pos,$start_pos")
        println(io, "end_pos,$end_pos")
        println(io, "m,$m")
        println(io, "p,", size(Sigma, 1))
        println(io, "nreps,", length(group_reps))
        println(io, "max_group_size,", countmap(groups) |> values |> collect |> maximum)
        println(io, "max_rep_group_size,", countmap(groups[group_reps]) |> values |> collect |> maximum)
        println(io, "import_sigma_time,$import_sigma_time")
        println(io, "def_group_time,$def_group_time")
        println(io, "solve_S_time,$solve_S_time")
    end

    return nothing
end

# use liftOver R package to add hg38 coordinates to Sigma_info
# SNPs that can't be converted, or if chr does not match after conversion, are deleted
function augment_hg38(Sigma_info, Sigma, chr, liftOver_chain_dir)
    pos = Sigma_info[!, "pos"]
    @rput chr pos liftOver_chain_dir
    R"""
    df<-cbind(data.frame(paste0('chr',chr)),pos,pos)
    colnames(df)<-c('chr','start','end')
    temp.Granges<-makeGRangesFromDataFrame(df)
    chain <- import.chain(liftOver_chain_dir)
    converted<-data.frame(liftOver(temp.Granges,chain))
    """
    @rget converted
    success_idx, pos_hg38 = falses(size(Sigma, 1)), Int[]
    for row in eachrow(converted)
        row["seqnames"] == "chr$chr" || continue # check chr match
        success_idx[row["group"]] = true
        push!(pos_hg38, row["start"])
    end
    Sigma_info_new = Sigma_info[success_idx, :]
    Sigma_new = Sigma[success_idx, success_idx]
    Sigma_info_new[!, :pos_hg19] = pos[success_idx]
    Sigma_info_new[!, :pos_hg38] = pos_hg38
    select!(Sigma_info_new, Not(:pos))
    return Sigma_new, Sigma_info_new
end

# function to rearrange the SNP orders to that resulting S2 and D2 actually block diagonal
function rearrange_snps!(groups, group_reps, Sigma, Sigma_info)
    perm = sortperm(groups)
    iperm = invperm(perm)
    groups .= @views groups[perm]
    group_reps .= @views iperm[group_reps]
    sort!(group_reps)
    @assert issorted(groups) && issorted(group_reps)
    Sigma .= @views Sigma[perm, perm]
    Sigma_info .= @views Sigma_info[perm, :]
    return nothing
end

# inputs to this script
bm_file = ARGS[1]                   # e.g. UKBB.EUR.ldadj.bm
ht_file = ARGS[2]                   # e.g. UKBB.EUR.ldadj.variant.ht
population = ARGS[3]
chr = ARGS[4]
start_pos = parse(Int, ARGS[5])
end_pos = parse(Int, ARGS[6])
method = Symbol(ARGS[7]) # maxent, mvr, or sdp
group_def = ARGS[8] # "hc" or "id"
remove_imputed_variants = parse(Bool, ARGS[9])
min_maf = parse(Float64, ARGS[10])
liftOver_chain_dir = ARGS[11]
outdir = ARGS[12]

# import typed SNP positions and ref/alt (used when remove_imputed_variants=true)
bimfile = "/oak/stanford/groups/zihuai/UKB_data/genotyped_call/ukb_cal_chr$(chr)_v2.bim"
typed_df = CSV.read(bimfile, DataFrame, header=false)
snps_to_keep = remove_imputed_variants ? typed_df[!, 4] : nothing

graphical_group_S(bm_file, ht_file, chr, start_pos, 
    end_pos, outdir, snps_to_keep=snps_to_keep, 
    method=method, group_def=group_def, 
    liftOver_chain_dir=liftOver_chain_dir)

# %% [markdown]
# ## Scripts to submit jobs
#
# + We need to solve 1703 blocks (for EUR panel), so we automate the job submission process with the script below
# + Each region requires ~5 min to solve
# + The Sherlock cluster accepts maximum of 1000 jobs per user, so we put some `sleep` commands in between job submissions to never exceed this number
#
# Overall, solving all regions should take 2 hours max.

# %%
using CSV, DataFrames

# chr = 1, 2, ..., or 22
# method = maxent, mvr, or sdp
# group_def = "hc" or "id"
function run_repeats(population, chr, method, group_def, remove_imputed_variants,
    min_maf; nsim=Inf)

    # find quasi-independent blocks
    region_file = "/oak/stanford/groups/zihuai/pan_ukb_LD_matrices/LD_block/$(population)_hg19/fourier_ls-all.bed"
    df = CSV.read(region_file, DataFrame)
    idx = findall(x -> x == "chr$chr ", df[!, 1])
    start_pos = df[idx, 2]
    end_pos = df[idx, 3] .- 1

    # prepare input parameters
    script_dir = "/oak/stanford/groups/zihuai/pan_ukb_group_knockoffs"
    liftOver_chain_dir = "/oak/stanford/groups/zihuai/GeneticsResources/LiftOver/hg19ToHg38.over.chain"
    bm_file = "/oak/stanford/groups/zihuai/pan_ukb_LD_matrices/UKBB.$population.ldadj.bm"
    ht_file = "/oak/stanford/groups/zihuai/pan_ukb_LD_matrices/UKBB.$population.ldadj.variant.ht"
    outdir = remove_imputed_variants ? 
        "/oak/stanford/groups/zihuai/pan_ukb_group_knockoffs/$population" : 
        "/oak/stanford/groups/zihuai/pan_ukb_group_knockoffs/$(population)_all"

    # submit 1 job per region
    counter = 0
    for (i, (s, e)) in enumerate(zip(start_pos, end_pos))
        # create .sh file to submit jobs
        filename = "submit.sh"
        open(filename, "w") do io
            println(io, "#!/bin/bash")
            println(io, "#")
            println(io, "#SBATCH --job-name=$(population)_$i")
            println(io, "#")
            println(io, "#SBATCH --time=6:00:00")
            println(io, "#SBATCH --cpus-per-task=1")
            println(io, "#SBATCH --mem-per-cpu=32G")
            println(io, "#SBATCH --partition=owners,normal,candes,zihuai")
            println(io, "#SBATCH --output=$(outdir)/slurms/slurm-%j.out")
            println(io, "")
            println(io, "#save job info on joblog:")
            println(io, "echo \"Job \$JOB_ID started on:   \" `hostname -s`")
            println(io, "echo \"Job \$JOB_ID started on:   \" `date `")
            println(io, "")
            println(io, "# load the job environment:")
            println(io, "ml julia/1.8.4 R/4.0.2 java/11.0.11 python/3.9.0 openssl/3.0.7 system")
            println(io, "export JULIA_DEPOT_PATH=\"/home/groups/sabatti/.julia\"")
            println(io, "")
            println(io, "# run code")
            println(io, "echo 'julia $(script_dir)/solve_blocks.jl $bm_file $ht_file $population $chr $s $e $method $group_def $remove_imputed_variants $min_maf $liftOver_chain_dir $outdir'")
            println(io, "julia $(script_dir)/solve_blocks.jl $bm_file $ht_file $population $chr $s $e $method $group_def $remove_imputed_variants $min_maf $liftOver_chain_dir $outdir")
            println(io, "")
            println(io, "#echo job info on joblog:")
            println(io, "echo \"Job \$JOB_ID ended on:   \" `hostname -s`")
            println(io, "echo \"Job \$JOB_ID ended on:   \" `date `")
            println(io, "#echo \" \"")
        end
        # submit job
        run(`sbatch $filename`)
        println("submitted chr$chr:$s-$e") 
        rm(filename, force=true)
        counter += 1
        counter ≥ nsim && break
    end
end

# test submission of 5 jobs
# population = "EUR"
# chr = 1
# method = "maxent"
# group_def = "hc"
# remove_imputed_variants = true
# min_maf = 0.01
# run_repeats(population, chr, method, group_def, remove_imputed_variants, min_maf, nsim=5)

method = "maxent"
group_def = "hc"
remove_imputed_variants = true
min_maf = 0.01
for population in ["EUR", "AFR", "EAS"]
    for chr in 1:7
        run_repeats(population, chr, method, group_def, remove_imputed_variants, min_maf)
    end
    sleep(600)

    for chr in 8:13
        run_repeats(population, chr, method, group_def, remove_imputed_variants, min_maf)
    end
    sleep(600)

    for chr in 14:22
        run_repeats(population, chr, method, group_def, remove_imputed_variants, min_maf)
    end
    sleep(600)
end
# Out:
# Submitted batch job 26428426
# submitted chr1:10583-1976557
# Submitted batch job 26428428
# submitted chr1:1976558-3492738
# Submitted batch job 26428430
# submitted chr1:3492739-4543011
# Submitted batch job 26428432
# submitted chr1:4543012-5914789
# Submitted batch job 26428434
# submitted chr1:5914790-7365001
# Submitted batch job 26428437
# submitted chr1:7365002-9002908
# Submitted batch job 26428439
# submitted chr1:9002909-10755519
# Submitted batch job 26428441
# submitted chr1:10755520-11708677
# Submitted batch job 26428444
# submitted chr1:11708678-13810999
# Submitted batch job 26428446
# submitted chr1:13811000-14893156
# Submitted batch job 26428448
# submitted chr1:14893157-17875819
# Submitted batch job 26428450
# submitted chr1:17875820-20304719
# Submitted batch job 26428453
# submitted chr1:20304720-22145805
# Submitted batch job 26428455
# submitted chr1:22145806-23916164
# Submitted batch job 26428458
# submitted chr1:23916165-25516892
# Submitted batch job 26428460
# submitted chr1:25516893-27400827
# Submitted batch job 26428462
# submitted chr1:27400828-30161896
# Submitted batch job 26428465
# submitted chr1:30161897-32043092
# Submitted batch job 26428467
# submitted chr1:32043093-34941266
# Submitted batch job 26428470
# submitted chr1:34941267-36857532
# Submitted batch job 26428474
# submitted chr1:36857533-39550620
# Submitted batch job 26428478
# submitted chr1:39550621-41288114
# Submitted batch job 26428481
# submitted chr1:41288115-43366278
# Submitted batch job 26428484
# submitted chr1:43366279-45082439
# Submitted batch job 26428489
# submitted chr1:45082440-47651004
# Submitted batch job 26428493
# submitted chr1:47651005-50644819
# Submitted batch job 26428497
# submitted chr1:50644820-54973024
# Submitted batch job 26428500
# submitted chr1:54973025-56412728
# Submitted batch job 26428504
# submitted chr1:56412729-57021654
# Submitted batch job 26428507
# submitted chr1:57021655-58196477
# Submitted batch job 26428510
# submitted chr1:58196478-59188244
# Submitted batch job 26428513
# submitted chr1:59188245-60232861
# Submitted batch job 26428516
# submitted chr1:60232862-62109987
# Submitted batch job 26428519
# submitted chr1:62109988-64095110
# Submitted batch job 26428522
# submitted chr1:64095111-65041375
# Submitted batch job 26428526
# submitted chr1:65041376-66774010
# Submitted batch job 26428529
# submitted chr1:66774011-68477861
# Submitted batch job 26428533
# submitted chr1:68477862-69687901
# Submitted batch job 26428536
# submitted chr1:69687902-72285465
# Submitted batch job 26428539
# submitted chr1:72285466-74327077
# Submitted batch job 26428542
# submitted chr1:74327078-76728119
# Submitted batch job 26428545
# submitted chr1:76728120-79112108
# Submitted batch job 26428548
# submitted chr1:79112109-80341731
# Submitted batch job 26428550
# submitted chr1:80341732-81990568
# Submitted batch job 26428554
# submitted chr1:81990569-83991643
# Submitted batch job 26428559
# submitted chr1:83991644-86012416
# Submitted batch job 26428564
# submitted chr1:86012417-88408032
# Submitted batch job 26428567
# submitted chr1:88408033-90066204
# Submitted batch job 26428570
# submitted chr1:90066205-92938313
# Submitted batch job 26428575
# submitted chr1:92938314-93568955
# Submitted batch job 26428579
# submitted chr1:93568956-96151206
# Submitted batch job 26428582
# submitted chr1:96151207-97949734
# Submitted batch job 26428585
# submitted chr1:97949735-99555995
# Submitted batch job 26428588
# submitted chr1:99555996-101849108
# Submitted batch job 26428591
# submitted chr1:101849109-102644326
# Submitted batch job 26428594
# submitted chr1:102644327-105413132
# Submitted batch job 26428597
# submitted chr1:105413133-106767763
# Submitted batch job 26428602
# submitted chr1:106767764-110304091
# Submitted batch job 26428605
# submitted chr1:110304092-112347255
# Submitted batch job 26428608
# submitted chr1:112347256-114872037
# Submitted batch job 26428611
# submitted chr1:114872038-118104014
# Submitted batch job 26428616
# submitted chr1:118104015-142545955
# Submitted batch job 26428620
# submitted chr1:142545956-147914608
# Submitted batch job 26428624
# submitted chr1:147914609-152537154
# Submitted batch job 26428627
# submitted chr1:152537155-153397054
# Submitted batch job 26428630
# submitted chr1:153397055-156616038
# Submitted batch job 26428633
# submitted chr1:156616039-157982578
# Submitted batch job 26428636
# submitted chr1:157982579-159953314
# Submitted batch job 26428639
# submitted chr1:159953315-162888863
# Submitted batch job 26428642
# submitted chr1:162888864-164954019
# Submitted batch job 26428647
# submitted chr1:164954020-168175844
# Submitted batch job 26428650
# submitted chr1:168175845-170169620
# Submitted batch job 26428653
# submitted chr1:170169621-172932965
# Submitted batch job 26428658
# submitted chr1:172932966-175387678
# Submitted batch job 26428661
# submitted chr1:175387679-177937440
# Submitted batch job 26428664
# submitted chr1:177937441-181116839
# Submitted batch job 26428668
# submitted chr1:181116840-183553325
# Submitted batch job 26428671
# submitted chr1:183553326-185513152
# Submitted batch job 26428674
# submitted chr1:185513153-187902800
# Submitted batch job 26428677
# submitted chr1:187902801-189761325
# Submitted batch job 26428680
# submitted chr1:189761326-191285921
# Submitted batch job 26428683
# submitted chr1:191285922-192349897
# Submitted batch job 26428686
# submitted chr1:192349898-194108440
# Submitted batch job 26428689
# submitted chr1:194108441-195996763
# Submitted batch job 26428722
# submitted chr1:195996764-198541161
# Submitted batch job 26428730
# submitted chr1:198541162-201071501
# Submitted batch job 26428733
# submitted chr1:201071502-203648599
# Submitted batch job 26428737
# submitted chr1:203648600-205271006
# Submitted batch job 26428740
# submitted chr1:205271007-208809069
# Submitted batch job 26428743
# submitted chr1:208809070-209837235
# Submitted batch job 26428746
# submitted chr1:209837236-212344929
# Submitted batch job 26428747
# submitted chr1:212344930-213936673
# Submitted batch job 26428750
# submitted chr1:213936674-216245664
# Submitted batch job 26428754
# submitted chr1:216245665-218342975
# Submitted batch job 26428757
# submitted chr1:218342976-220125115
# Submitted batch job 26428760
# submitted chr1:220125116-221151628
# Submitted batch job 26428763
# submitted chr1:221151629-223654494
# Submitted batch job 26428767
# submitted chr1:223654495-225965357
# Submitted batch job 26428770
# submitted chr1:225965358-228102731
# Submitted batch job 26428774
# submitted chr1:228102732-230437261
# Submitted batch job 26428778
# submitted chr1:230437262-232090251
# Submitted batch job 26428781
# submitted chr1:232090252-233369740
# Submitted batch job 26428783
# submitted chr1:233369741-234839042
# Submitted batch job 26428784
# submitted chr1:234839043-236202704
# Submitted batch job 26428785
# submitted chr1:236202705-237419494
# Submitted batch job 26428786
# submitted chr1:237419495-238922340
# Submitted batch job 26428788
# submitted chr1:238922341-239566654
# Submitted batch job 26428789
# submitted chr1:239566655-241169136
# Submitted batch job 26428790
# submitted chr1:241169137-242420887
# Submitted batch job 26428791
# submitted chr1:242420888-244512786
# Submitted batch job 26428792
# submitted chr1:244512787-245966753
# Submitted batch job 26428793
# submitted chr1:245966754-247344629
# Submitted batch job 26428794
# submitted chr1:247344630-249239465
# Submitted batch job 26428795
# submitted chr2:10133-2645947
# Submitted batch job 26428801
# submitted chr2:2645948-4015664
# Submitted batch job 26428806
# submitted chr2:4015665-5529461
# Submitted batch job 26428810
# submitted chr2:5529462-6967942
# Submitted batch job 26428814
# submitted chr2:6967943-8233380
# Submitted batch job 26428817
# submitted chr2:8233381-10083948
# Submitted batch job 26428821
# submitted chr2:10083949-12419386
# Submitted batch job 26428825
# submitted chr2:12419387-14757212
# Submitted batch job 26428829
# submitted chr2:14757213-16549756
# Submitted batch job 26428833
# submitted chr2:16549757-17515330
# Submitted batch job 26428836
# submitted chr2:17515331-19692795
# Submitted batch job 26428838
# submitted chr2:19692796-20402937
# Submitted batch job 26428840
# submitted chr2:20402938-23703343
# Submitted batch job 26428842
# submitted chr2:23703344-26209578
# Submitted batch job 26428844
# submitted chr2:26209579-29456859
# Submitted batch job 26428846
# submitted chr2:29456860-31111553
# Submitted batch job 26428848
# submitted chr2:31111554-33363143
# Submitted batch job 26428850
# submitted chr2:33363144-34016908
# Submitted batch job 26428852
# submitted chr2:34016909-35344927
# Submitted batch job 26428853
# submitted chr2:35344928-36123027
# Submitted batch job 26428855
# submitted chr2:36123028-38132910
# Submitted batch job 26428857
# submitted chr2:38132911-40508069
# Submitted batch job 26428859
# submitted chr2:40508070-42336743
# Submitted batch job 26428861
# submitted chr2:42336744-44322127
# Submitted batch job 26428863
# submitted chr2:44322128-46482633
# Submitted batch job 26428865
# submitted chr2:46482634-47806039
# Submitted batch job 26428875
# submitted chr2:47806040-49116025
# Submitted batch job 26428878
# submitted chr2:49116026-50818255
# Submitted batch job 26428880
# submitted chr2:50818256-52491016
# Submitted batch job 26428882
# submitted chr2:52491017-53355221
# Submitted batch job 26428885
# submitted chr2:53355222-54686321
# Submitted batch job 26428888
# submitted chr2:54686322-57429034
# Submitted batch job 26428890
# submitted chr2:57429035-57726343
# Submitted batch job 26428893
# submitted chr2:57726344-60728135
# Submitted batch job 26428895
# submitted chr2:60728136-62429043
# Submitted batch job 26428898
# submitted chr2:62429044-64625084
# Submitted batch job 26428901
# submitted chr2:64625085-65936331
# Submitted batch job 26428904
# submitted chr2:65936332-67227247
# Submitted batch job 26428906
# submitted chr2:67227248-69375741
# Submitted batch job 26428909
# submitted chr2:69375742-70579921
# Submitted batch job 26428912
# submitted chr2:70579922-73125597
# Submitted batch job 26428915
# submitted chr2:73125598-75409632
# Submitted batch job 26428917
# submitted chr2:75409633-76647376
# Submitted batch job 26428920
# submitted chr2:76647377-78080013
# Submitted batch job 26428922
# submitted chr2:78080014-80049717
# Submitted batch job 26428924
# submitted chr2:80049718-83606073
# Submitted batch job 26428926
# submitted chr2:83606074-85893190
# Submitted batch job 26428928
# submitted chr2:85893191-86961901
# Submitted batch job 26428930
# submitted chr2:86961902-89260646
# Submitted batch job 26428932
# submitted chr2:89260647-95326809
# Submitted batch job 26428934
# submitted chr2:95326810-98629108
# Submitted batch job 26428937
# submitted chr2:98629109-100544637
# Submitted batch job 26428941
# submitted chr2:100544638-101557233
# Submitted batch job 26428943
# submitted chr2:101557234-103759507
# Submitted batch job 26428945
# submitted chr2:103759508-104714864
# Submitted batch job 26428948
# submitted chr2:104714865-107780931
# Submitted batch job 26428950
# submitted chr2:107780932-108996017
# Submitted batch job 26428952
# submitted chr2:108996018-113477210
# Submitted batch job 26428957
# submitted chr2:113477211-116413650
# Submitted batch job 26428959
# submitted chr2:116413651-119581737
# Submitted batch job 26428961
# submitted chr2:119581738-121554316
# Submitted batch job 26428964
# submitted chr2:121554317-123396004
# Submitted batch job 26428966
# submitted chr2:123396005-124932992
# Submitted batch job 26428968
# submitted chr2:124932993-127752361
# Submitted batch job 26428970
# submitted chr2:127752362-129313013
# Submitted batch job 26428972
# submitted chr2:129313014-131767128
# Submitted batch job 26428977
# submitted chr2:131767129-132783543
# Submitted batch job 26428979
# submitted chr2:132783544-135158692
# Submitted batch job 26428983
# submitted chr2:135158693-136977975
# Submitted batch job 26428985
# submitted chr2:136977976-139414543
# Submitted batch job 26428988
# submitted chr2:139414544-140903957
# Submitted batch job 26428990
# submitted chr2:140903958-142793065
# Submitted batch job 26428993
# submitted chr2:142793066-144519477
# Submitted batch job 26428996
# submitted chr2:144519478-147956519
# Submitted batch job 26429000
# submitted chr2:147956520-150473192
# Submitted batch job 26429003
# submitted chr2:150473193-153465187
# Submitted batch job 26429006
# submitted chr2:153465188-155637293
# Submitted batch job 26429009
# submitted chr2:155637294-157560494
# Submitted batch job 26429011
# submitted chr2:157560495-159577114
# Submitted batch job 26429012
# submitted chr2:159577115-161769654
# Submitted batch job 26429014
# submitted chr2:161769655-163503839
# Submitted batch job 26429015
# submitted chr2:163503840-165203972
# Submitted batch job 26429016
# submitted chr2:165203973-167128465
# Submitted batch job 26429017
# submitted chr2:167128466-167490427
# Submitted batch job 26429018
# submitted chr2:167490428-169588987
# Submitted batch job 26429019
# submitted chr2:169588988-171319416
# Submitted batch job 26429056
# submitted chr2:171319417-174122649
# Submitted batch job 26429057
# submitted chr2:174122650-177074922
# Submitted batch job 26429058
# submitted chr2:177074923-179244503
# Submitted batch job 26429059
# submitted chr2:179244504-181812684
# Submitted batch job 26429111
# submitted chr2:181812685-184145975
# Submitted batch job 26429112
# submitted chr2:184145976-186242926
# Submitted batch job 26429113
# submitted chr2:186242927-188897633
# Submitted batch job 26429114
# submitted chr2:188897634-191973454
# Submitted batch job 26429115
# submitted chr2:191973455-195123358
# Submitted batch job 26429116
# submitted chr2:195123359-197140124
# Submitted batch job 26429117
# submitted chr2:197140125-198142796
# Submitted batch job 26429118
# submitted chr2:198142797-200513799
# Submitted batch job 26429119
# submitted chr2:200513800-201357288
# Submitted batch job 26429120
# submitted chr2:201357289-202542474
# Submitted batch job 26429121
# submitted chr2:202542475-205363046
# Submitted batch job 26429122
# submitted chr2:205363047-208120623
# Submitted batch job 26429123
# submitted chr2:208120624-209941698
# Submitted batch job 26429124
# submitted chr2:209941699-212194774
# Submitted batch job 26429125
# submitted chr2:212194775-214013652
# Submitted batch job 26429126
# submitted chr2:214013653-215573225
# Submitted batch job 26429127
# submitted chr2:215573226-218395306
# Submitted batch job 26429128
# submitted chr2:218395307-219853566
# Submitted batch job 26429129
# submitted chr2:219853567-222520903
# Submitted batch job 26429130
# submitted chr2:222520904-224859322
# Submitted batch job 26429132
# submitted chr2:224859323-227665677
# Submitted batch job 26429134
# submitted chr2:227665678-229593914
# Submitted batch job 26429136
# submitted chr2:229593915-232191249
# Submitted batch job 26429139
# submitted chr2:232191250-233550712
# Submitted batch job 26429141
# submitted chr2:233550713-234883166
# Submitted batch job 26429143
# submitted chr2:234883167-236066959
# Submitted batch job 26429145
# submitted chr2:236066960-237201265
# Submitted batch job 26429147
# submitted chr2:237201266-238502380
# Submitted batch job 26429149
# submitted chr2:238502381-240328717
# Submitted batch job 26429151
# submitted chr2:240328718-241459496
# Submitted batch job 26429153
# submitted chr2:241459497-242489408
# Submitted batch job 26429155
# submitted chr2:242489409-243188919
# Submitted batch job 26429157
# submitted chr3:60157-1164056
# Submitted batch job 26429159
# submitted chr3:1164057-2863910
# Submitted batch job 26429161
# submitted chr3:2863911-5108348
# Submitted batch job 26429163
# submitted chr3:5108349-6724764
# Submitted batch job 26429165
# submitted chr3:6724765-8051950
# Submitted batch job 26429167
# submitted chr3:8051951-9899532
# Submitted batch job 26429170
# submitted chr3:9899533-11019487
# Submitted batch job 26429172
# submitted chr3:11019488-12860228
# Submitted batch job 26429174
# submitted chr3:12860229-14816749
# Submitted batch job 26429176
# submitted chr3:14816750-16664546
# Submitted batch job 26429178
# submitted chr3:16664547-17891040
# Submitted batch job 26429180
# submitted chr3:17891041-19789002
# Submitted batch job 26429182
# submitted chr3:19789003-20375344
# Submitted batch job 26429184
# submitted chr3:20375345-21643706
# Submitted batch job 26429186
# submitted chr3:21643707-22647519
# Submitted batch job 26429189
# submitted chr3:22647520-25460046
# Submitted batch job 26429191
# submitted chr3:25460047-27611776
# Submitted batch job 26429193
# submitted chr3:27611777-30484624
# Submitted batch job 26429195
# submitted chr3:30484625-31726059
# Submitted batch job 26429197
# submitted chr3:31726060-32845662
# Submitted batch job 26429199
# submitted chr3:32845663-33989245
# Submitted batch job 26429201
# submitted chr3:33989246-35283407
# Submitted batch job 26429203
# submitted chr3:35283408-38353504
# Submitted batch job 26429205
# submitted chr3:38353505-40796031
# Submitted batch job 26429209
# submitted chr3:40796032-42540433
# Submitted batch job 26429211
# submitted chr3:42540434-45151575
# Submitted batch job 26429213
# submitted chr3:45151576-45992976
# Submitted batch job 26429216
# submitted chr3:45992977-47793552
# Submitted batch job 26429218
# submitted chr3:47793553-51831791
# Submitted batch job 26429221
# submitted chr3:51831792-53739788
# Submitted batch job 26429223
# submitted chr3:53739789-55348767
# Submitted batch job 26429225
# submitted chr3:55348768-56847830
# Submitted batch job 26429227
# submitted chr3:56847831-59704330
# Submitted batch job 26429229
# submitted chr3:59704331-61958749
# Submitted batch job 26429232
# submitted chr3:61958750-63669878
# Submitted batch job 26429234
# submitted chr3:63669879-65273078
# Submitted batch job 26429236
# submitted chr3:65273079-66270446
# Submitted batch job 26429238
# submitted chr3:66270447-67742900
# Submitted batch job 26429241
# submitted chr3:67742901-68646217
# Submitted batch job 26429244
# submitted chr3:68646218-70449027
# Submitted batch job 26429247
# submitted chr3:70449028-72528425
# Submitted batch job 26429250
# submitted chr3:72528426-74398939
# Submitted batch job 26429253
# submitted chr3:74398940-75717385
# Submitted batch job 26429256
# submitted chr3:75717386-79024470
# Submitted batch job 26429258
# submitted chr3:79024471-82022275
# Submitted batch job 26429260
# submitted chr3:82022276-82527030
# Submitted batch job 26429263
# submitted chr3:82527031-84961749
# Submitted batch job 26429265
# submitted chr3:84961750-87590635
# Submitted batch job 26429268
# submitted chr3:87590636-89775032
# Submitted batch job 26429270
# submitted chr3:89775033-94256162
# Submitted batch job 26429273
# submitted chr3:94256163-96058346
# Submitted batch job 26429276
# submitted chr3:96058347-98215515
# Submitted batch job 26429279
# submitted chr3:98215516-100553824
# Submitted batch job 26429281
# submitted chr3:100553825-102013408
# Submitted batch job 26429283
# submitted chr3:102013409-104581612
# Submitted batch job 26429285
# submitted chr3:104581613-106834266
# Submitted batch job 26429287
# submitted chr3:106834267-108638227
# Submitted batch job 26429289
# submitted chr3:108638228-110929055
# Submitted batch job 26429291
# submitted chr3:110929056-112455116
# Submitted batch job 26429293
# submitted chr3:112455117-113650585
# Submitted batch job 26429296
# submitted chr3:113650586-115605660
# Submitted batch job 26429298
# submitted chr3:115605661-116898041
# Submitted batch job 26429300
# submitted chr3:116898042-118903461
# Submitted batch job 26429302
# submitted chr3:118903462-120523072
# Submitted batch job 26429304
# submitted chr3:120523073-121822626
# Submitted batch job 26429305
# submitted chr3:121822627-123198640
# Submitted batch job 26429306
# submitted chr3:123198641-124936548
# Submitted batch job 26429307
# submitted chr3:124936549-126214329
# Submitted batch job 26429308
# submitted chr3:126214330-128194795
# Submitted batch job 26429309
# submitted chr3:128194796-130024575
# Submitted batch job 26429310
# submitted chr3:130024576-131836225
# Submitted batch job 26429311
# submitted chr3:131836226-133573171
# Submitted batch job 26429312
# submitted chr3:133573172-135268751
# Submitted batch job 26429313
# submitted chr3:135268752-137727494
# Submitted batch job 26429314
# submitted chr3:137727495-139847178
# Submitted batch job 26429315
# submitted chr3:139847179-141034490
# Submitted batch job 26429316
# submitted chr3:141034491-142985099
# Submitted batch job 26429317
# submitted chr3:142985100-144169279
# Submitted batch job 26429318
# submitted chr3:144169280-146285124
# Submitted batch job 26429319
# submitted chr3:146285125-148637332
# Submitted batch job 26429320
# submitted chr3:148637333-150530064
# Submitted batch job 26429321
# submitted chr3:150530065-151256351
# Submitted batch job 26429322
# submitted chr3:151256352-152222142
# Submitted batch job 26429323
# submitted chr3:152222143-153407525
# Submitted batch job 26429324
# submitted chr3:153407526-154485880
# Submitted batch job 26429325
# submitted chr3:154485881-157311595
# Submitted batch job 26429326
# submitted chr3:157311596-159155376
# Submitted batch job 26429327
# submitted chr3:159155377-161620008
# Submitted batch job 26429328
# submitted chr3:161620009-165935730
# Submitted batch job 26429329
# submitted chr3:165935731-168270618
# Submitted batch job 26429330
# submitted chr3:168270619-172048456
# Submitted batch job 26429331
# submitted chr3:172048457-175051222
# Submitted batch job 26429332
# submitted chr3:175051223-176928974
# Submitted batch job 26429333
# submitted chr3:176928975-179376587
# Submitted batch job 26429334
# submitted chr3:179376588-181637722
# Submitted batch job 26429335
# submitted chr3:181637723-184112681
# Submitted batch job 26429336
# submitted chr3:184112682-186230741
# Submitted batch job 26429337
# submitted chr3:186230742-188951596
# Submitted batch job 26429338
# submitted chr3:188951597-190355508
# Submitted batch job 26429339
# submitted chr3:190355509-192344596
# Submitted batch job 26429340
# submitted chr3:192344597-193962111
# Submitted batch job 26429341
# submitted chr3:193962112-195349065
# Submitted batch job 26429342
# submitted chr3:195349066-196728481
# Submitted batch job 26429343
# submitted chr3:196728482-197946621
# Submitted batch job 26429344
# submitted chr4:10240-695911
# Submitted batch job 26429345
# submitted chr4:695912-2306582
# Submitted batch job 26429346
# submitted chr4:2306583-3384843
# Submitted batch job 26429347
# submitted chr4:3384844-4989587
# Submitted batch job 26429348
# submitted chr4:4989588-6325241
# Submitted batch job 26429349
# submitted chr4:6325242-7663189
# Submitted batch job 26429351
# submitted chr4:7663190-9217083
# Submitted batch job 26429352
# submitted chr4:9217084-10698979
# Submitted batch job 26429353
# submitted chr4:10698980-13004347
# Submitted batch job 26429354
# submitted chr4:13004348-15148515
# Submitted batch job 26429355
# submitted chr4:15148516-16579694
# Submitted batch job 26429356
# submitted chr4:16579695-18752292
# Submitted batch job 26429357
# submitted chr4:18752293-20486650
# Submitted batch job 26429358
# submitted chr4:20486651-22319287
# Submitted batch job 26429359
# submitted chr4:22319288-24135368
# Submitted batch job 26429360
# submitted chr4:24135369-26836316
# Submitted batch job 26429361
# submitted chr4:26836317-29313036
# Submitted batch job 26429362
# submitted chr4:29313037-31205516
# Submitted batch job 26429363
# submitted chr4:31205517-32593452
# Submitted batch job 26429364
# submitted chr4:32593453-35151581
# Submitted batch job 26429365
# submitted chr4:35151582-36540809
# Submitted batch job 26429366
# submitted chr4:36540810-38203463
# Submitted batch job 26429367
# submitted chr4:38203464-40588392
# Submitted batch job 26429368
# submitted chr4:40588393-42664296
# Submitted batch job 26429369
# submitted chr4:42664297-45189269
# Submitted batch job 26429370
# submitted chr4:45189270-47412252
# Submitted batch job 26429371
# submitted chr4:47412253-47997644
# Submitted batch job 26429372
# submitted chr4:47997645-54658564
# Submitted batch job 26429373
# submitted chr4:54658565-57458941
# Submitted batch job 26429374
# submitted chr4:57458942-59360440
# Submitted batch job 26429375
# submitted chr4:59360441-60608828
# Submitted batch job 26429376
# submitted chr4:60608829-61598882
# Submitted batch job 26429377
# submitted chr4:61598883-63843685
# Submitted batch job 26429378
# submitted chr4:63843686-64504613
# Submitted batch job 26429379
# submitted chr4:64504614-65592227
# Submitted batch job 26429380
# submitted chr4:65592228-68741352
# Submitted batch job 26429381
# submitted chr4:68741353-69601807
# Submitted batch job 26429382
# submitted chr4:69601808-72418005
# Submitted batch job 26429383
# submitted chr4:72418006-74888946
# Submitted batch job 26429384
# submitted chr4:74888947-77718851
# Submitted batch job 26429385
# submitted chr4:77718852-78969419
# Submitted batch job 26429386
# submitted chr4:78969420-80322664
# Submitted batch job 26429387
# submitted chr4:80322665-82691668
# Submitted batch job 26429388
# submitted chr4:82691669-83510371
# Submitted batch job 26429389
# submitted chr4:83510372-84922153
# Submitted batch job 26429390
# submitted chr4:84922154-87214992
# Submitted batch job 26429391
# submitted chr4:87214993-89236854
# Submitted batch job 26429392
# submitted chr4:89236855-90500459
# Submitted batch job 26429393
# submitted chr4:90500460-92166235
# Submitted batch job 26429394
# submitted chr4:92166236-94233167
# Submitted batch job 26429395
# submitted chr4:94233168-95896912
# Submitted batch job 26429396
# submitted chr4:95896913-97912514
# Submitted batch job 26429397
# submitted chr4:97912515-99040830
# Submitted batch job 26429398
# submitted chr4:99040831-101711688
# Submitted batch job 26429399
# submitted chr4:101711689-102707192
# Submitted batch job 26429400
# submitted chr4:102707193-105305538
# Submitted batch job 26429401
# submitted chr4:105305539-107501340
# Submitted batch job 26429402
# submitted chr4:107501341-109780300
# Submitted batch job 26429403
# submitted chr4:109780301-111466212
# Submitted batch job 26429404
# submitted chr4:111466213-114687994
# Submitted batch job 26429405
# submitted chr4:114687995-118224724
# Submitted batch job 26429406
# submitted chr4:118224725-119932619
# Submitted batch job 26429407
# submitted chr4:119932620-121393950
# Submitted batch job 26429408
# submitted chr4:121393951-122458884
# Submitted batch job 26429409
# submitted chr4:122458885-124387407
# Submitted batch job 26429411
# submitted chr4:124387408-126751238
# Submitted batch job 26429412
# submitted chr4:126751239-127833072
# Submitted batch job 26429413
# submitted chr4:127833073-130591860
# Submitted batch job 26429414
# submitted chr4:130591861-131284304
# Submitted batch job 26429415
# submitted chr4:131284305-133742119
# Submitted batch job 26429416
# submitted chr4:133742120-134111557
# Submitted batch job 26429417
# submitted chr4:134111558-135954225
# Submitted batch job 26429418
# submitted chr4:135954226-137831941
# Submitted batch job 26429419
# submitted chr4:137831942-139197293
# Submitted batch job 26429420
# submitted chr4:139197294-143226783
# Submitted batch job 26429421
# submitted chr4:143226784-145025809
# Submitted batch job 26429422
# submitted chr4:145025810-148834276
# Submitted batch job 26429423
# submitted chr4:148834277-150683432
# Submitted batch job 26429424
# submitted chr4:150683433-152782183
# Submitted batch job 26429426
# submitted chr4:152782184-154122369
# Submitted batch job 26429427
# submitted chr4:154122370-155546838
# Submitted batch job 26429428
# submitted chr4:155546839-157596252
# Submitted batch job 26429429
# submitted chr4:157596253-158455362
# Submitted batch job 26429430
# submitted chr4:158455363-161798201
# Submitted batch job 26429432
# submitted chr4:161798202-161998783
# Submitted batch job 26429436
# submitted chr4:161998784-163413309
# Submitted batch job 26429439
# submitted chr4:163413310-164173866
# Submitted batch job 26429440
# submitted chr4:164173867-165472928
# Submitted batch job 26429441
# submitted chr4:165472929-166593951
# Submitted batch job 26429442
# submitted chr4:166593952-167853559
# Submitted batch job 26429443
# submitted chr4:167853560-169676675
# Submitted batch job 26429444
# submitted chr4:169676676-171209591
# Submitted batch job 26429445
# submitted chr4:171209592-172963784
# Submitted batch job 26429457
# submitted chr4:172963785-174857041
# Submitted batch job 26429459
# submitted chr4:174857042-176376341
# Submitted batch job 26429462
# submitted chr4:176376342-179391122
# Submitted batch job 26429464
# submitted chr4:179391123-180547907
# Submitted batch job 26429467
# submitted chr4:180547908-183473283
# Submitted batch job 26429469
# submitted chr4:183473284-184930022
# Submitted batch job 26429471
# submitted chr4:184930023-186544263
# Submitted batch job 26429473
# submitted chr4:186544264-187867532
# Submitted batch job 26429475
# submitted chr4:187867533-189155113
# Submitted batch job 26429478
# submitted chr4:189155114-189915202
# Submitted batch job 26429480
# submitted chr4:189915203-191043593
# Submitted batch job 26429483
# submitted chr5:11940-1483179
# Submitted batch job 26429485
# submitted chr5:1483180-2851268
# Submitted batch job 26429488
# submitted chr5:2851269-4940254
# Submitted batch job 26429490
# submitted chr5:4940255-5973035
# Submitted batch job 26429492
# submitted chr5:5973036-8445401
# Submitted batch job 26429495
# submitted chr5:8445402-9873005
# Submitted batch job 26429498
# submitted chr5:9873006-11849589
# Submitted batch job 26429500
# submitted chr5:11849590-13611630
# Submitted batch job 26429502
# submitted chr5:13611631-17400371
# Submitted batch job 26429506
# submitted chr5:17400372-18850603
# Submitted batch job 26429508
# submitted chr5:18850604-22657007
# Submitted batch job 26429510
# submitted chr5:22657008-23719695
# Submitted batch job 26429513
# submitted chr5:23719696-26124487
# Submitted batch job 26429516
# submitted chr5:26124488-27316596
# Submitted batch job 26429527
# submitted chr5:27316597-29594523
# Submitted batch job 26429532
# submitted chr5:29594524-31391125
# Submitted batch job 26429534
# submitted chr5:31391126-33500817
# Submitted batch job 26429537
# submitted chr5:33500818-35048571
# Submitted batch job 26429539
# submitted chr5:35048572-36433091
# Submitted batch job 26429542
# submitted chr5:36433092-38802787
# Submitted batch job 26429545
# submitted chr5:38802788-40287728
# Submitted batch job 26429548
# submitted chr5:40287729-42858746
# Submitted batch job 26429551
# submitted chr5:42858747-44045379
# Submitted batch job 26429553
# submitted chr5:44045380-49410914
# Submitted batch job 26429556
# submitted chr5:49410915-51701348
# Submitted batch job 26429558
# submitted chr5:51701349-53748306
# Submitted batch job 26429563
# submitted chr5:53748307-55416657
# Submitted batch job 26429601
# submitted chr5:55416658-57339004
# Submitted batch job 26429603
# submitted chr5:57339005-58523944
# Submitted batch job 26429605
# submitted chr5:58523945-61247123
# Submitted batch job 26429607
# submitted chr5:61247124-62536057
# Submitted batch job 26429609
# submitted chr5:62536058-65205426
# Submitted batch job 26429612
# submitted chr5:65205427-67851516
# Submitted batch job 26429651
# submitted chr5:67851517-71419710
# Submitted batch job 26429653
# submitted chr5:71419711-73759198
# Submitted batch job 26429656
# submitted chr5:73759199-76221197
# Submitted batch job 26429658
# submitted chr5:76221198-77283974
# Submitted batch job 26429661
# submitted chr5:77283975-79394040
# Submitted batch job 26429665
# submitted chr5:79394041-79992757
# Submitted batch job 26429669
# submitted chr5:79992758-81237240
# Submitted batch job 26429672
# submitted chr5:81237241-83972772
# Submitted batch job 26429674
# submitted chr5:83972773-85767056
# Submitted batch job 26429677
# submitted chr5:85767057-87438019
# Submitted batch job 26429681
# submitted chr5:87438020-90423338
# Submitted batch job 26429684
# submitted chr5:90423339-91840636
# Submitted batch job 26429687
# submitted chr5:91840637-93811096
# Submitted batch job 26429690
# submitted chr5:93811097-96374149
# Submitted batch job 26429693
# submitted chr5:96374150-97316374
# Submitted batch job 26429695
# submitted chr5:97316375-99261849
# Submitted batch job 26429698
# submitted chr5:99261850-100595233
# Submitted batch job 26429700
# submitted chr5:100595234-103181350
# Submitted batch job 26429703
# submitted chr5:103181351-104854816
# Submitted batch job 26429705
# submitted chr5:104854817-106909040
# Submitted batch job 26429707
# submitted chr5:106909041-109233617
# Submitted batch job 26429712
# submitted chr5:109233618-110896790
# Submitted batch job 26429715
# submitted chr5:110896791-112302829
# Submitted batch job 26429717
# submitted chr5:112302830-113777985
# Submitted batch job 26429719
# submitted chr5:113777986-114751102
# Submitted batch job 26429722
# submitted chr5:114751103-115879776
# Submitted batch job 26429725
# submitted chr5:115879777-117082849
# Submitted batch job 26429727
# submitted chr5:117082850-118675900
# Submitted batch job 26429733
# submitted chr5:118675901-119669845
# Submitted batch job 26429755
# submitted chr5:119669846-122002652
# Submitted batch job 26429758
# submitted chr5:122002653-123240669
# Submitted batch job 26429761
# submitted chr5:123240670-125128469
# Submitted batch job 26429767
# submitted chr5:125128470-127345467
# Submitted batch job 26429769
# submitted chr5:127345468-129519146
# Submitted batch job 26429773
# submitted chr5:129519147-132007337
# Submitted batch job 26429775
# submitted chr5:132007338-134777576
# Submitted batch job 26429778
# submitted chr5:134777577-136376491
# Submitted batch job 26429781
# submitted chr5:136376492-139409052
# Submitted batch job 26429785
# submitted chr5:139409053-141852076
# Submitted batch job 26429787
# submitted chr5:141852077-143592975
# Submitted batch job 26429790
# submitted chr5:143592976-146434799
# Submitted batch job 26429793
# submitted chr5:146434800-148549093
# Submitted batch job 26429797
# submitted chr5:148549094-150911274
# Submitted batch job 26429799
# submitted chr5:150911275-152504699
# Submitted batch job 26429802
# submitted chr5:152504700-153899306
# Submitted batch job 26429805
# submitted chr5:153899307-156627809
# Submitted batch job 26429808
# submitted chr5:156627810-157585547
# Submitted batch job 26429810
# submitted chr5:157585548-159866696
# Submitted batch job 26429813
# submitted chr5:159866697-161694488
# Submitted batch job 26429817
# submitted chr5:161694489-163803606
# Submitted batch job 26429819
# submitted chr5:163803607-165314601
# Submitted batch job 26429821
# submitted chr5:165314602-167651858
# Submitted batch job 26429824
# submitted chr5:167651859-169330610
# Submitted batch job 26429826
# submitted chr5:169330611-170904980
# Submitted batch job 26429829
# submitted chr5:170904981-172766001
# Submitted batch job 26429831
# submitted chr5:172766002-174167622
# Submitted batch job 26429833
# submitted chr5:174167623-176509937
# Submitted batch job 26429835
# submitted chr5:176509938-179096401
# Submitted batch job 26429838
# submitted chr5:179096402-179828924
# Submitted batch job 26429840
# submitted chr5:179828925-180885155
# Submitted batch job 26429841
# submitted chr6:73924-1452082
# Submitted batch job 26429844
# submitted chr6:1452083-2510435
# Submitted batch job 26429846
# submitted chr6:2510436-4317568
# Submitted batch job 26429848
# submitted chr6:4317569-5057820
# Submitted batch job 26429850
# submitted chr6:5057821-6752796
# Submitted batch job 26429852
# submitted chr6:6752797-7975636
# Submitted batch job 26429854
# submitted chr6:7975637-9020423
# Submitted batch job 26429857
# submitted chr6:9020424-10627075
# Submitted batch job 26429859
# submitted chr6:10627076-12365128
# Submitted batch job 26429862
# submitted chr6:12365129-13835829
# Submitted batch job 26429864
# submitted chr6:13835830-15819454
# Submitted batch job 26429866
# submitted chr6:15819455-18404206
# Submitted batch job 26429868
# submitted chr6:18404207-19672631
# Submitted batch job 26429870
# submitted chr6:19672632-23199919
# Submitted batch job 26429873
# submitted chr6:23199920-24397128
# Submitted batch job 26429876
# submitted chr6:24397129-26141756
# Submitted batch job 26429879
# submitted chr6:26141757-26697552
# Submitted batch job 26429881
# submitted chr6:26697553-28901401
# Submitted batch job 26429883
# submitted chr6:28901402-29688045
# Submitted batch job 26429886
# submitted chr6:29688046-30458590
# Submitted batch job 26429889
# submitted chr6:30458591-31054922
# Submitted batch job 26429891
# submitted chr6:31054923-31571893
# Submitted batch job 26429897
# submitted chr6:31571894-32682589
# Submitted batch job 26429900
# submitted chr6:32682590-33209309
# Submitted batch job 26429902
# submitted chr6:33209310-35757006
# Submitted batch job 26429904
# submitted chr6:35757007-37112680
# Submitted batch job 26429906
# submitted chr6:37112681-39022822
# Submitted batch job 26429907
# submitted chr6:39022823-40434090
# Submitted batch job 26429909
# submitted chr6:40434091-41712057
# Submitted batch job 26429912
# submitted chr6:41712058-43728478
# Submitted batch job 26429914
# submitted chr6:43728479-45405388
# Submitted batch job 26429917
# submitted chr6:45405389-46731323
# Submitted batch job 26429919
# submitted chr6:46731324-49957252
# Submitted batch job 26429921
# submitted chr6:49957253-51171479
# Submitted batch job 26429923
# submitted chr6:51171480-52828868
# Submitted batch job 26429925
# submitted chr6:52828869-54293677
# Submitted batch job 26429928
# submitted chr6:54293678-56105706
# Submitted batch job 26429930
# submitted chr6:56105707-58138274
# Submitted batch job 26429933
# submitted chr6:58138275-62693822
# Submitted batch job 26429934
# submitted chr6:62693823-64607598
# Submitted batch job 26429935
# submitted chr6:64607599-65764775
# Submitted batch job 26429936
# submitted chr6:65764776-67152225
# Submitted batch job 26429938
# submitted chr6:67152226-67906135
# Submitted batch job 26429939
# submitted chr6:67906136-70361483
# Submitted batch job 26429940
# submitted chr6:70361484-71609004
# Submitted batch job 26429941
# submitted chr6:71609005-73451672
# Submitted batch job 26429942
# submitted chr6:73451673-74404067
# Submitted batch job 26429944
# submitted chr6:74404068-76627638
# Submitted batch job 26429946
# submitted chr6:76627639-77415154
# Submitted batch job 26429947
# submitted chr6:77415155-78385576
# Submitted batch job 26429950
# submitted chr6:78385577-80691481
# Submitted batch job 26429951
# submitted chr6:80691482-82389310
# Submitted batch job 26429952
# submitted chr6:82389311-84742340
# Submitted batch job 26429953
# submitted chr6:84742341-87650462
# Submitted batch job 26429954
# submitted chr6:87650463-88857391
# Submitted batch job 26429956
# submitted chr6:88857392-91092351
# Submitted batch job 26429958
# submitted chr6:91092352-92348704
# Submitted batch job 26429959
# submitted chr6:92348705-94329243
# Submitted batch job 26429961
# submitted chr6:94329244-96490133
# Submitted batch job 26429963
# submitted chr6:96490134-98021636
# Submitted batch job 26429964
# submitted chr6:98021637-100875515
# Submitted batch job 26429965
# submitted chr6:100875516-102201823
# Submitted batch job 26429966
# submitted chr6:102201824-104733703
# Submitted batch job 26429967
# submitted chr6:104733704-107240061
# Submitted batch job 26429968
# submitted chr6:107240062-108858459
# Submitted batch job 26429970
# submitted chr6:108858460-110305070
# Submitted batch job 26429971
# submitted chr6:110305071-112345455
# Submitted batch job 26429972
# submitted chr6:112345456-114220832
# Submitted batch job 26429973
# submitted chr6:114220833-116703925
# Submitted batch job 26429974
# submitted chr6:116703926-118099643
# Submitted batch job 26429975
# submitted chr6:118099644-120338587
# Submitted batch job 26429976
# submitted chr6:120338588-122348427
# Submitted batch job 26429977
# submitted chr6:122348428-124099183
# Submitted batch job 26429978
# submitted chr6:124099184-127540154
# Submitted batch job 26429979
# submitted chr6:127540155-129860935
# Submitted batch job 26429980
# submitted chr6:129860936-130935710
# Submitted batch job 26429981
# submitted chr6:130935711-132891665
# Submitted batch job 26429982
# submitted chr6:132891666-134243917
# Submitted batch job 26429983
# submitted chr6:134243918-136223663
# Submitted batch job 26429984
# submitted chr6:136223664-138245744
# Submitted batch job 26429985
# submitted chr6:138245745-139976686
# Submitted batch job 26429986
# submitted chr6:139976687-142288532
# Submitted batch job 26429987
# submitted chr6:142288533-145518029
# Submitted batch job 26429988
# submitted chr6:145518030-147740271
# Submitted batch job 26429989
# submitted chr6:147740272-150754999
# Submitted batch job 26429990
# submitted chr6:150755000-152702384
# Submitted batch job 26429991
# submitted chr6:152702385-153993092
# Submitted batch job 26429992
# submitted chr6:153993093-157641071
# Submitted batch job 26429993
# submitted chr6:157641072-159542045
# Submitted batch job 26429994
# submitted chr6:159542046-162169451
# Submitted batch job 26429995
# submitted chr6:162169452-164360066
# Submitted batch job 26429996
# submitted chr6:164360067-166831723
# Submitted batch job 26429997
# submitted chr6:166831724-168042467
# Submitted batch job 26429998
# submitted chr6:168042468-169236970
# Submitted batch job 26429999
# submitted chr6:169236971-169946665
# Submitted batch job 26430000
# submitted chr6:169946666-171051269
# Submitted batch job 26430001
# submitted chr7:16161-1240746
# Submitted batch job 26430002
# submitted chr7:1240747-2482289
# Submitted batch job 26430003
# submitted chr7:2482290-4142452
# Submitted batch job 26430004
# submitted chr7:4142453-5455377
# Submitted batch job 26430005
# submitted chr7:5455378-6573086
# Submitted batch job 26430006
# submitted chr7:6573087-8162907
# Submitted batch job 26430007
# submitted chr7:8162908-9034683
# Submitted batch job 26430008
# submitted chr7:9034684-10882976
# Submitted batch job 26430009
# submitted chr7:10882977-12635430
# Submitted batch job 26430010
# submitted chr7:12635431-14141607
# Submitted batch job 26430011
# submitted chr7:14141608-15591420
# Submitted batch job 26430012
# submitted chr7:15591421-16902523
# Submitted batch job 26430013
# submitted chr7:16902524-18759805
# Submitted batch job 26430015
# submitted chr7:18759806-21715377
# Submitted batch job 26430016
# submitted chr7:21715378-23472032
# Submitted batch job 26430017
# submitted chr7:23472033-26552260
# Submitted batch job 26430018
# submitted chr7:26552261-28554103
# Submitted batch job 26430019
# submitted chr7:28554104-31137288
# Submitted batch job 26430021
# submitted chr7:31137289-33997076
# Submitted batch job 26430022
# submitted chr7:33997077-36120152
# Submitted batch job 26430027
# submitted chr7:36120153-37910001
# Submitted batch job 26430030
# submitted chr7:37910002-38965628
# Submitted batch job 26430032
# submitted chr7:38965629-40482672
# Submitted batch job 26430033
# submitted chr7:40482673-41853481
# Submitted batch job 26430034
# submitted chr7:41853482-43448396
# Submitted batch job 26430035
# submitted chr7:43448397-45523272
# Submitted batch job 26430036
# submitted chr7:45523273-47104275
# Submitted batch job 26430037
# submitted chr7:47104276-49211847
# Submitted batch job 26430038
# submitted chr7:49211848-51674879
# Submitted batch job 26430039
# submitted chr7:51674880-53176375
# Submitted batch job 26430040
# submitted chr7:53176376-54905958
# Submitted batch job 26430041
# submitted chr7:54905959-57382763
# Submitted batch job 26430042
# submitted chr7:57382764-62560321
# Submitted batch job 26430043
# submitted chr7:62560322-63624321
# Submitted batch job 26430044
# submitted chr7:63624322-67371494
# Submitted batch job 26430045
# submitted chr7:67371495-68458763
# Submitted batch job 26430046
# submitted chr7:68458764-69083423
# Submitted batch job 26430047
# submitted chr7:69083424-71874125
# Submitted batch job 26430048
# submitted chr7:71874126-74408522
# Submitted batch job 26430049
# submitted chr7:74408523-76499311
# Submitted batch job 26430055
# submitted chr7:76499312-78460634
# Submitted batch job 26430056
# submitted chr7:78460635-80333321
# Submitted batch job 26430057
# submitted chr7:80333322-81714242
# Submitted batch job 26430058
# submitted chr7:81714243-83567545
# Submitted batch job 26430059
# submitted chr7:83567546-85570788
# Submitted batch job 26430060
# submitted chr7:85570789-88189328
# Submitted batch job 26430061
# submitted chr7:88189329-89727015
# Submitted batch job 26430066
# submitted chr7:89727016-92494244
# Submitted batch job 26430067
# submitted chr7:92494245-94058817
# Submitted batch job 26430068
# submitted chr7:94058818-96432922
# Submitted batch job 26430069
# submitted chr7:96432923-99365082
# Submitted batch job 26430070
# submitted chr7:99365083-100526289
# Submitted batch job 26430071
# submitted chr7:100526290-101731497
# Submitted batch job 26430072
# submitted chr7:101731498-103197910
# Submitted batch job 26430073
# submitted chr7:103197911-103793048
# Submitted batch job 26430074
# submitted chr7:103793049-105681589
# Submitted batch job 26430075
# submitted chr7:105681590-107460000
# Submitted batch job 26430076
# submitted chr7:107460001-109296361
# Submitted batch job 26430077
# submitted chr7:109296362-112125630
# Submitted batch job 26430078
# submitted chr7:112125631-113714772
# Submitted batch job 26430079
# submitted chr7:113714773-116918287
# Submitted batch job 26430080
# submitted chr7:116918288-119074051
# Submitted batch job 26430081
# submitted chr7:119074052-120269170
# Submitted batch job 26430082
# submitted chr7:120269171-122992989
# Submitted batch job 26430083
# submitted chr7:122992990-125775065
# Submitted batch job 26430084
# submitted chr7:125775066-126869220
# Submitted batch job 26430085
# submitted chr7:126869221-129589867
# Submitted batch job 26430086
# submitted chr7:129589868-131635482
# Submitted batch job 26430087
# submitted chr7:131635483-133736373
# Submitted batch job 26430088
# submitted chr7:133736374-136111688
# Submitted batch job 26430090
# submitted chr7:136111689-138309841
# Submitted batch job 26430091
# submitted chr7:138309842-139664084
# Submitted batch job 26430092
# submitted chr7:139664085-141678416
# Submitted batch job 26430093
# submitted chr7:141678417-142659757
# Submitted batch job 26430094
# submitted chr7:142659758-145171421
# Submitted batch job 26430097
# submitted chr7:145171422-146397903
# Submitted batch job 26430099
# submitted chr7:146397904-147996404
# Submitted batch job 26430101
# submitted chr7:147996405-149500991
# Submitted batch job 26430102
# submitted chr7:149500992-151627122
# Submitted batch job 26430104
# submitted chr7:151627123-153033737
# Submitted batch job 26430105
# submitted chr7:153033738-154964315
# Submitted batch job 26430106
# submitted chr7:154964316-156153105
# Submitted batch job 26430107
# submitted chr7:156153106-157635552
# Submitted batch job 26430108
# submitted chr7:157635553-159128574
# Submitted batch job 26431107
# submitted chr8:10422-720793
# Submitted batch job 26431110
# submitted chr8:720794-1162979
# Submitted batch job 26431113
# submitted chr8:1162980-1957007
# Submitted batch job 26431115
# submitted chr8:1957008-2791986
# Submitted batch job 26431117
# submitted chr8:2791987-3361149
# Submitted batch job 26431118
# submitted chr8:3361150-3704712
# Submitted batch job 26431122
# submitted chr8:3704713-4480373
# Submitted batch job 26431125
# submitted chr8:4480374-5146926
# Submitted batch job 26431129
# submitted chr8:5146927-6142330
# Submitted batch job 26431132
# submitted chr8:6142331-7153078
# Submitted batch job 26431136
# submitted chr8:7153079-9099580
# Submitted batch job 26431140
# submitted chr8:9099581-10118213
# Submitted batch job 26431143
# submitted chr8:10118214-11088308
# Submitted batch job 26431147
# submitted chr8:11088309-13394642
# Submitted batch job 26431151
# submitted chr8:13394643-13945975
# Submitted batch job 26431154
# submitted chr8:13945976-15709610
# Submitted batch job 26431158
# submitted chr8:15709611-17300378
# Submitted batch job 26431161
# submitted chr8:17300379-18671054
# Submitted batch job 26431164
# submitted chr8:18671055-19221079
# Submitted batch job 26431167
# submitted chr8:19221080-21137818
# Submitted batch job 26431171
# submitted chr8:21137819-21901217
# Submitted batch job 26431174
# submitted chr8:21901218-23028334
# Submitted batch job 26431177
# submitted chr8:23028335-24672500
# Submitted batch job 26431180
# submitted chr8:24672501-25803979
# Submitted batch job 26431183
# submitted chr8:25803980-26900698
# Submitted batch job 26431186
# submitted chr8:26900699-28621012
# Submitted batch job 26431190
# submitted chr8:28621013-30534247
# Submitted batch job 26431194
# submitted chr8:30534248-33044703
# Submitted batch job 26431197
# submitted chr8:33044704-34782250
# Submitted batch job 26431200
# submitted chr8:34782251-38017235
# Submitted batch job 26431201
# submitted chr8:38017236-40054434
# Submitted batch job 26431204
# submitted chr8:40054435-42472799
# Submitted batch job 26431207
# submitted chr8:42472800-46841314
# Submitted batch job 26431210
# submitted chr8:46841315-51464549
# Submitted batch job 26431213
# submitted chr8:51464550-53885290
# Submitted batch job 26431215
# submitted chr8:53885291-54450916
# Submitted batch job 26431218
# submitted chr8:54450917-56115357
# Submitted batch job 26431221
# submitted chr8:56115358-57212082
# Submitted batch job 26431223
# submitted chr8:57212083-59047311
# Submitted batch job 26431229
# submitted chr8:59047312-60470379
# Submitted batch job 26431232
# submitted chr8:60470380-62328608
# Submitted batch job 26431235
# submitted chr8:62328609-63426171
# Submitted batch job 26431238
# submitted chr8:63426172-67414033
# Submitted batch job 26431241
# submitted chr8:67414034-69121035
# Submitted batch job 26431245
# submitted chr8:69121036-72289570
# Submitted batch job 26431259
# submitted chr8:72289571-73836478
# Submitted batch job 26431262
# submitted chr8:73836479-75684314
# Submitted batch job 26431265
# submitted chr8:75684315-77379450
# Submitted batch job 26431268
# submitted chr8:77379451-79751439
# ...
# Submitted batch job 26432228
# submitted chr15:55823743-56865254
# Submitted batch job 26432229
# submitted chr15:56865255-58828305
# Submitted batch job 26432230
# submitted chr15:58828306-59909704
# Submitted batch job 26432231
# submitted chr15:59909705-61292485
# Submitted batch job 26432232
# submitted chr15:61292486-63015121
# Submitted batch job 26432233
# submitted chr15:63015122-64339747
# Submitted batch job 26432234
# submitted chr15:64339748-67468816
# Submitted batch job 26432235
# submitted chr15:67468817-68891517
# Submitted batch job 26432236
# submitted chr15:68891518-72047166
# Submitted batch job 26432237
# submitted chr15:72047167-73628713
# Submitted batch job 26432238
# submitted chr15:73628714-76398690
# Submitted batch job 26432240
# submitted chr15:76398691-78516008
# Submitted batch job 26432241
# submitted chr15:78516009-80638743
# Submitted batch job 26432242
# submitted chr15:80638744-84260702
# Submitted batch job 26432243
# submitted chr15:84260703-86652258
# Submitted batch job 26432244
# submitted chr15:86652259-88370261
# Submitted batch job 26432245
# submitted chr15:88370262-90070117
# Submitted batch job 26432246
# submitted chr15:90070118-92011844
# Submitted batch job 26432248
# submitted chr15:92011845-93591317
# Submitted batch job 26432249
# submitted chr15:93591318-94922390
# Submitted batch job 26432250
# submitted chr15:94922391-96473836
# Submitted batch job 26432254
# submitted chr15:96473837-98030719
# Submitted batch job 26432264
# submitted chr15:98030720-100290015
# Submitted batch job 26432265
# submitted chr15:100290016-102520965
# Submitted batch job 26432266
# submitted chr16:60054-1107355
# Submitted batch job 26432267
# submitted chr16:1107356-2410639
# Submitted batch job 26432268
# submitted chr16:2410640-4046569
# Submitted batch job 26432270
# submitted chr16:4046570-5117846
# Submitted batch job 26432271
# submitted chr16:5117847-5855101
# Submitted batch job 26432272
# submitted chr16:5855102-6893426
# Submitted batch job 26432273
# submitted chr16:6893427-7604975
# Submitted batch job 26432274
# submitted chr16:7604976-8961639
# Submitted batch job 26432275
# submitted chr16:8961640-10868120
# Submitted batch job 26432276
# submitted chr16:10868121-12612115
# Submitted batch job 26432277
# submitted chr16:12612116-13154642
# Submitted batch job 26432278
# submitted chr16:13154643-14470774
# Submitted batch job 26432279
# submitted chr16:14470775-16960199
# Submitted batch job 26432280
# submitted chr16:16960200-18102735
# Submitted batch job 26432281
# submitted chr16:18102736-20151005
# Submitted batch job 26432282
# submitted chr16:20151006-21499396
# Submitted batch job 26432283
# submitted chr16:21499397-24309955
# Submitted batch job 26432284
# submitted chr16:24309956-25725415
# Submitted batch job 26432286
# submitted chr16:25725416-27795174
# Submitted batch job 26432287
# submitted chr16:27795175-29698605
# Submitted batch job 26432289
# submitted chr16:29698606-32703170
# Submitted batch job 26432291
# submitted chr16:32703171-49008732
# Submitted batch job 26432293
# submitted chr16:49008733-51214362
# Submitted batch job 26432307
# submitted chr16:51214363-54450243
# Submitted batch job 26432309
# submitted chr16:54450244-56907577
# Submitted batch job 26432310
# submitted chr16:56907578-58867357
# Submitted batch job 26432311
# submitted chr16:58867358-60746326
# Submitted batch job 26432312
# submitted chr16:60746327-62227635
# Submitted batch job 26432326
# submitted chr16:62227636-63691588
# Submitted batch job 26432328
# submitted chr16:63691589-66398030
# Submitted batch job 26432329
# submitted chr16:66398031-69541876
# Submitted batch job 26432331
# submitted chr16:69541877-73543800
# Submitted batch job 26432333
# submitted chr16:73543801-74971510
# Submitted batch job 26432334
# submitted chr16:74971511-76275793
# Submitted batch job 26432336
# submitted chr16:76275794-77523906
# Submitted batch job 26432337
# submitted chr16:77523907-78865570
# Submitted batch job 26432339
# submitted chr16:78865571-80297073
# Submitted batch job 26432340
# submitted chr16:80297074-81432838
# Submitted batch job 26432343
# submitted chr16:81432839-82747942
# Submitted batch job 26432345
# submitted chr16:82747943-83612984
# Submitted batch job 26432348
# submitted chr16:83612985-84445737
# Submitted batch job 26432349
# submitted chr16:84445738-85374252
# Submitted batch job 26432351
# submitted chr16:85374253-86981135
# Submitted batch job 26432352
# submitted chr16:86981136-88704476
# Submitted batch job 26432353
# submitted chr16:88704477-90292811
# Submitted batch job 26432355
# submitted chr17:56-1173000
# Submitted batch job 26432356
# submitted chr17:1173001-2632815
# Submitted batch job 26432358
# submitted chr17:2632816-3591294
# Submitted batch job 26432360
# submitted chr17:3591295-5574964
# Submitted batch job 26432361
# submitted chr17:5574965-6634093
# Submitted batch job 26432362
# submitted chr17:6634094-9312565
# Submitted batch job 26432363
# submitted chr17:9312566-10575137
# Submitted batch job 26432364
# submitted chr17:10575138-12534587
# Submitted batch job 26432365
# submitted chr17:12534588-13464479
# Submitted batch job 26432366
# submitted chr17:13464480-14215664
# Submitted batch job 26432367
# submitted chr17:14215665-15280575
# Submitted batch job 26432368
# submitted chr17:15280576-16437684
# Submitted batch job 26432369
# submitted chr17:16437685-18853177
# Submitted batch job 26432370
# submitted chr17:18853178-21285187
# Submitted batch job 26432371
# submitted chr17:21285188-26802477
# Submitted batch job 26432372
# submitted chr17:26802478-29266625
# Submitted batch job 26432373
# submitted chr17:29266626-31695392
# Submitted batch job 26432375
# submitted chr17:31695393-32911703
# Submitted batch job 26432376
# submitted chr17:32911704-34395060
# Submitted batch job 26432377
# submitted chr17:34395061-36495388
# Submitted batch job 26432378
# submitted chr17:36495389-38649588
# Submitted batch job 26432381
# submitted chr17:38649589-39900527
# Submitted batch job 26432382
# submitted chr17:39900528-43932380
# Submitted batch job 26432384
# submitted chr17:43932381-45880184
# Submitted batch job 26432385
# submitted chr17:45880185-49895547
# Submitted batch job 26432386
# submitted chr17:49895548-51665572
# Submitted batch job 26432387
# submitted chr17:51665573-53597455
# Submitted batch job 26432389
# submitted chr17:53597456-55680272
# Submitted batch job 26432390
# submitted chr17:55680273-57488350
# Submitted batch job 26432392
# submitted chr17:57488351-59650640
# Submitted batch job 26432394
# submitted chr17:59650641-63102443
# Submitted batch job 26432395
# submitted chr17:63102444-64800165
# Submitted batch job 26432397
# submitted chr17:64800166-67858769
# Submitted batch job 26432398
# submitted chr17:67858770-69546298
# Submitted batch job 26432399
# submitted chr17:69546299-72789311
# Submitted batch job 26432401
# submitted chr17:72789312-75392711
# Submitted batch job 26432402
# submitted chr17:75392712-77326227
# Submitted batch job 26432404
# submitted chr17:77326228-79044910
# Submitted batch job 26432406
# submitted chr17:79044911-81194907
# Submitted batch job 26432407
# submitted chr18:10644-2405379
# Submitted batch job 26432409
# submitted chr18:2405380-3542106
# Submitted batch job 26432410
# submitted chr18:3542107-5154577
# Submitted batch job 26432412
# submitted chr18:5154578-7133193
# Submitted batch job 26432414
# submitted chr18:7133194-8467003
# Submitted batch job 26432415
# submitted chr18:8467004-10845312
# Submitted batch job 26432417
# submitted chr18:10845313-12024367
# Submitted batch job 26432418
# submitted chr18:12024368-14439638
# Submitted batch job 26432419
# submitted chr18:14439639-19485843
# Submitted batch job 26432421
# submitted chr18:19485844-20790475
# Submitted batch job 26432422
# submitted chr18:20790476-22895522
# Submitted batch job 26432424
# submitted chr18:22895523-24025115
# Submitted batch job 26432425
# submitted chr18:24025116-25760876
# Submitted batch job 26432426
# submitted chr18:25760877-27429486
# Submitted batch job 26432428
# submitted chr18:27429487-29368666
# Submitted batch job 26432430
# submitted chr18:29368667-31424982
# Submitted batch job 26432432
# submitted chr18:31424983-33794595
# Submitted batch job 26432433
# submitted chr18:33794596-35838350
# Submitted batch job 26432434
# submitted chr18:35838351-36979960
# Submitted batch job 26432436
# submitted chr18:36979961-38767937
# Submitted batch job 26432437
# submitted chr18:38767938-40990733
# Submitted batch job 26432438
# submitted chr18:40990734-42921885
# Submitted batch job 26432439
# submitted chr18:42921886-44155068
# Submitted batch job 26432441
# submitted chr18:44155069-46208354
# Submitted batch job 26432443
# submitted chr18:46208355-47730998
# Submitted batch job 26432445
# submitted chr18:47730999-51061436
# Submitted batch job 26432446
# submitted chr18:51061437-52517131
# Submitted batch job 26432447
# submitted chr18:52517132-54958663
# Submitted batch job 26432449
# submitted chr18:54958664-57377706
# Submitted batch job 26432450
# submitted chr18:57377707-58232802
# Submitted batch job 26432452
# submitted chr18:58232803-60278228
# Submitted batch job 26432453
# submitted chr18:60278229-61818996
# Submitted batch job 26432454
# submitted chr18:61818997-62898665
# Submitted batch job 26432455
# submitted chr18:62898666-65106560
# Submitted batch job 26432456
# submitted chr18:65106561-66205922
# Submitted batch job 26432457
# submitted chr18:66205923-68813476
# Submitted batch job 26432459
# submitted chr18:68813477-70096915
# Submitted batch job 26432460
# submitted chr18:70096916-72982758
# Submitted batch job 26432462
# submitted chr18:72982759-74459353
# Submitted batch job 26432463
# submitted chr18:74459354-75975852
# Submitted batch job 26432464
# submitted chr18:75975853-77149288
# Submitted batch job 26432466
# submitted chr18:77149289-78017157
# Submitted batch job 26432467
# submitted chr19:80840-759260
# Submitted batch job 26432469
# submitted chr19:759261-1347380
# Submitted batch job 26432470
# submitted chr19:1347381-3179689
# Submitted batch job 26432472
# submitted chr19:3179690-5377036
# Submitted batch job 26432474
# submitted chr19:5377037-6893559
# Submitted batch job 26432477
# submitted chr19:6893560-9016692
# Submitted batch job 26432479
# submitted chr19:9016693-9383876
# Submitted batch job 26432481
# submitted chr19:9383877-11849448
# Submitted batch job 26432484
# submitted chr19:11849449-12500148
# Submitted batch job 26432486
# submitted chr19:12500149-15648147
# Submitted batch job 26432488
# submitted chr19:15648148-16749207
# Submitted batch job 26432491
# submitted chr19:16749208-20221312
# Submitted batch job 26432492
# submitted chr19:20221313-21822863
# Submitted batch job 26432493
# submitted chr19:21822864-23466053
# Submitted batch job 26432495
# submitted chr19:23466054-27741110
# Submitted batch job 26432497
# submitted chr19:27741111-29789973
# Submitted batch job 26432499
# submitted chr19:29789974-30600791
# Submitted batch job 26432500
# submitted chr19:30600792-32440023
# Submitted batch job 26432502
# submitted chr19:32440024-34205225
# Submitted batch job 26432503
# submitted chr19:34205226-36468277
# Submitted batch job 26432505
# submitted chr19:36468278-38726450
# Submitted batch job 26432506
# submitted chr19:38726451-41446534
# Submitted batch job 26432507
# submitted chr19:41446535-41948682
# Submitted batch job 26432509
# submitted chr19:41948683-43862454
# Submitted batch job 26432510
# submitted chr19:43862455-45579042
# Submitted batch job 26432511
# submitted chr19:45579043-47334408
# Submitted batch job 26432513
# submitted chr19:47334409-49093111
# Submitted batch job 26432514
# submitted chr19:49093112-51334270
# Submitted batch job 26432516
# submitted chr19:51334271-52985346
# Submitted batch job 26432517
# submitted chr19:52985347-54734183
# Submitted batch job 26432519
# submitted chr19:54734184-55660891
# Submitted batch job 26432520
# submitted chr19:55660892-57195057
# Submitted batch job 26432521
# submitted chr19:57195058-59118838
# Submitted batch job 26432523
# submitted chr20:60479-2244038
# Submitted batch job 26432525
# submitted chr20:2244039-3147023
# Submitted batch job 26432526
# submitted chr20:3147024-5415567
# Submitted batch job 26432528
# submitted chr20:5415568-6669966
# Submitted batch job 26432529
# submitted chr20:6669967-8602104
# Submitted batch job 26432531
# submitted chr20:8602105-9591196
# Submitted batch job 26432532
# submitted chr20:9591197-11014703
# Submitted batch job 26432533
# submitted chr20:11014704-12154277
# Submitted batch job 26432535
# submitted chr20:12154278-13689324
# Submitted batch job 26432536
# submitted chr20:13689325-15543675
# Submitted batch job 26432538
# submitted chr20:15543676-17753798
# Submitted batch job 26432539
# submitted chr20:17753799-19110600
# Submitted batch job 26432541
# submitted chr20:19110601-21683222
# Submitted batch job 26432542
# submitted chr20:21683223-22740663
# Submitted batch job 26432544
# submitted chr20:22740664-24060964
# Submitted batch job 26432545
# submitted chr20:24060965-31047797
# Submitted batch job 26432546
# submitted chr20:31047798-34960771
# Submitted batch job 26432548
# submitted chr20:34960772-36954723
# Submitted batch job 26432549
# submitted chr20:36954724-39083842
# Submitted batch job 26432551
# submitted chr20:39083843-41198419
# Submitted batch job 26432554
# submitted chr20:41198420-43060136
# Submitted batch job 26432555
# submitted chr20:43060137-44814231
# Submitted batch job 26432556
# submitted chr20:44814232-47198829
# Submitted batch job 26432558
# submitted chr20:47198830-49239657
# Submitted batch job 26432559
# submitted chr20:49239658-52472371
# Submitted batch job 26432560
# submitted chr20:52472372-54142340
# Submitted batch job 26432562
# submitted chr20:54142341-56512593
# Submitted batch job 26432563
# submitted chr20:56512594-58104564
# Submitted batch job 26432565
# submitted chr20:58104565-60242139
# Submitted batch job 26432567
# submitted chr20:60242140-60765009
# Submitted batch job 26432568
# submitted chr20:60765010-62189092
# Submitted batch job 26432570
# submitted chr20:62189093-62965162
# Submitted batch job 26432571
# submitted chr21:9411243-15842926
# Submitted batch job 26432573
# submitted chr21:15842927-17889942
# Submitted batch job 26432574
# submitted chr21:17889943-19332405
# Submitted batch job 26432576
# submitted chr21:19332406-21056779
# Submitted batch job 26432577
# submitted chr21:21056780-22883607
# Submitted batch job 26432579
# submitted chr21:22883608-25333577
# Submitted batch job 26432580
# submitted chr21:25333578-26470747
# Submitted batch job 26432582
# submitted chr21:26470748-29125074
# Submitted batch job 26432583
# submitted chr21:29125075-30846394
# Submitted batch job 26432584
# submitted chr21:30846395-32814464
# Submitted batch job 26432586
# submitted chr21:32814465-35407942
# Submitted batch job 26432587
# submitted chr21:35407943-36355772
# Submitted batch job 26432589
# submitted chr21:36355773-38040880
# Submitted batch job 26432590
# submitted chr21:38040881-39830619
# Submitted batch job 26432592
# submitted chr21:39830620-41389309
# Submitted batch job 26432595
# submitted chr21:41389310-43321527
# Submitted batch job 26432597
# submitted chr21:43321528-44504004
# Submitted batch job 26432600
# submitted chr21:44504005-46176126
# Submitted batch job 26432602
# submitted chr21:46176127-47031780
# Submitted batch job 26432603
# submitted chr21:47031781-48119751
# Submitted batch job 26432605
# submitted chr22:16050408-17581546
# Submitted batch job 26432606
# submitted chr22:17581547-18557030
# Submitted batch job 26432608
# submitted chr22:18557031-19912241
# Submitted batch job 26432609
# submitted chr22:19912242-21986826
# Submitted batch job 26432610
# submitted chr22:21986827-23398336
# Submitted batch job 26432612
# submitted chr22:23398337-25209348
# Submitted batch job 26432613
# submitted chr22:25209349-26524343
# Submitted batch job 26432614
# submitted chr22:26524344-28233389
# Submitted batch job 26432617
# submitted chr22:28233390-30954396
# Submitted batch job 26432618
# submitted chr22:30954397-32665506
# Submitted batch job 26432620
# submitted chr22:32665507-34860925
# Submitted batch job 26432622
# submitted chr22:34860926-36453607
# Submitted batch job 26432624
# submitted chr22:36453608-37977989
# Submitted batch job 26432626
# submitted chr22:37977990-40527059
# Submitted batch job 26432627
# submitted chr22:40527060-42690817
# Submitted batch job 26432629
# submitted chr22:42690818-44994945
# Submitted batch job 26432630
# submitted chr22:44994946-46915048
# Submitted batch job 26432631
# submitted chr22:46915049-48212128
# Submitted batch job 26432633
# submitted chr22:48212129-49800745
# Submitted batch job 26432635
# submitted chr22:49800746-51243297

# %% [markdown]
# Submit a job to automatically run block above

# %%
function submit(command::String, cpus, total_mem; jobname="submit")
    per_cpu_mem = round(Int, total_mem / cpus)
    # create .sh file to submit jobs
    filename = "submit.sh"
    open(filename, "w") do io
        println(io, "#!/bin/bash")
        println(io, "#")
        println(io, "#SBATCH --job-name=$jobname")
        println(io, "#")
        println(io, "#SBATCH --time=24:00:00")
        println(io, "#SBATCH --cpus-per-task=$cpus")
        println(io, "#SBATCH --mem-per-cpu=$(per_cpu_mem)G")
        println(io, "#SBATCH --partition=normal,candes,zihuai")
        println(io, "")
        println(io, "#save job info on joblog:")
        println(io, "echo \"Job \$JOB_ID started on:   \" `hostname -s`")
        println(io, "echo \"Job \$JOB_ID started on:   \" `date `")
        println(io, "")
        println(io, "# load the job environment:")
        println(io, "module load julia/1.8.4")
        println(io, "export JULIA_DEPOT_PATH=\"/home/groups/sabatti/.julia\"")
        println(io, "")
        println(io, "# run code")
        println(io, "echo '$command'")
        println(io, command)
        println(io, "")
        println(io, "#echo job info on joblog:")
        println(io, "echo \"Job \$JOB_ID ended on:   \" `hostname -s`")
        println(io, "echo \"Job \$JOB_ID ended on:   \" `date `")
        println(io, "#echo \" \"")
    end
    # submit job
    run(`sbatch $filename`)
end

command = "julia /oak/stanford/groups/zihuai/pan_ukb_group_knockoffs/submit_solve_blocks.jl"
submit(command, 1, 4, jobname="delegator")
# Out:
# Submitted batch job 26366026
# Process(`sbatch submit.sh`, ProcessExited(0))

# %% [markdown]
# ## Scripts to check for failed jobs and resubmit them
#
# On 4/14/2023, failed 67 / 5109 jobs

# %%
using CSV, DataFrames

function submit(command::String, outdir)
    # create .sh file to submit jobs
    filename = "resubmit.sh"
    open(filename, "w") do io
        println(io, "#!/bin/bash")
        println(io, "#")
        println(io, "#SBATCH --job-name=resubmit")
        println(io, "#")
        println(io, "#SBATCH --time=4:00:00")
        println(io, "#SBATCH --cpus-per-task=1")
        println(io, "#SBATCH --mem-per-cpu=64G")
        println(io, "#SBATCH --partition=owners,normal,candes,zihuai")
        println(io, "#SBATCH --output=$(outdir)/slurms/slurm-%j.out")
        println(io, "")
        println(io, "#save job info on joblog:")
        println(io, "echo \"Job \$JOB_ID started on:   \" `hostname -s`")
        println(io, "echo \"Job \$JOB_ID started on:   \" `date `")
        println(io, "")
        println(io, "# load the job environment:")
        println(io, "ml julia/1.8.4 R/4.0.2 java/11.0.11 python/3.9.0 openssl/3.0.7 system")
        println(io, "export JULIA_DEPOT_PATH=\"/home/groups/sabatti/.julia\"")
        println(io, "")
        println(io, "# run code")
        println(io, "echo '$command'")
        println(io, command)
        println(io, "")
        println(io, "#echo job info on joblog:")
        println(io, "echo \"Job \$JOB_ID ended on:   \" `hostname -s`")
        println(io, "echo \"Job \$JOB_ID ended on:   \" `date `")
        println(io, "#echo \" \"")
    end
    # submit job
    run(`sbatch $filename`)
    println("submitted command: $command") 
    rm(filename, force=true)
end

method = "maxent"
group_def = "hc"
remove_imputed_variants = true
min_maf = 0.01
population = "EAS" #["EUR", "AFR", "EAS"]

# find quasi-independent blocks
region_file = "/oak/stanford/groups/zihuai/pan_ukb_LD_matrices/LD_block/$(population)_hg19/fourier_ls-all.bed"
df = CSV.read(region_file, DataFrame)
idx = findall(x -> x == "chr$chr ", df[!, 1])
start_pos = df[idx, 2]
end_pos = df[idx, 3] .- 1

# prepare input parameters
script_dir = "/oak/stanford/groups/zihuai/pan_ukb_group_knockoffs"
liftOver_chain_dir = "/oak/stanford/groups/zihuai/GeneticsResources/LiftOver/hg19ToHg38.over.chain"
bm_file = "/oak/stanford/groups/zihuai/pan_ukb_LD_matrices/UKBB.$population.ldadj.bm"
ht_file = "/oak/stanford/groups/zihuai/pan_ukb_LD_matrices/UKBB.$population.ldadj.variant.ht"
outdir = remove_imputed_variants ? 
    "/oak/stanford/groups/zihuai/pan_ukb_group_knockoffs/$population" : 
    "/oak/stanford/groups/zihuai/pan_ukb_group_knockoffs/$(population)_all"

failed = 0
for chr in 1:22
    idx = findall(x -> x == "chr$chr ", df[!, 1])
    start_pos = df[idx, 2]
    end_pos = df[idx, 3] .- 1
    for (s, e) in zip(start_pos, end_pos)
        LDfile = joinpath(outdir, "chr$chr", "LD_start$(s)_end$(e).h5")
        summary_file = joinpath(outdir, "chr$chr","summary_start$(s)_end$(e).csv")
        info_file = joinpath(outdir, "chr$chr","Info_start$(s)_end$(e).csv")
        if !(isfile(LDfile) && isfile(summary_file) && isfile(info_file))
            command = "julia $(script_dir)/solve_blocks.jl $bm_file $ht_file $population $chr $s $e $method $group_def $remove_imputed_variants $min_maf $liftOver_chain_dir $outdir"
            submit(command, outdir)
            failed += 1
        end
    end
end
println("$population failed $failed jobs")
# Out:
# EAS failed 0 jobs
